# %% [markdown]
# # Loading Postgresql Database with Yelp Data
#
#
# Objective: To upload `business` and `reviews` datat to Postgres RDS

# %%
import os
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# Load pandas dataframe
def load_data(url):
    if url.endswith(".csv") or "csv" in url:
        df = pd.read_csv(url)
    else:
        df = None
    return df

# %% [markdown]
# ## Load `business` to Postgres

# %%
biz_url = 'https://tally-ai-dspt3.s3.amazonaws.com/yelp-restaurants/business_with_cuisine.csv'

business = load_data(biz_url)
business = business.drop(columns=["Unnamed: 0"])
business.head()
# Out:
#    Unnamed: 0.1               address  \
# 0             0  2706 E University Dr
# 1           139    1017 E Apache Blvd
# 2           258  4005 N Scottsdale Rd
# 3           993               S Tryon
# 4          1174       20825 N Pima Rd
#
#                                           attributes             business_id  \
# 0  {'Caters': 'False', 'OutdoorSeating': 'False',...  j9bWpCRwpDVfwVT_V85qeA
# 1  {'NoiseLevel': "u'average'", 'BusinessAcceptsC...  W7hCuNdn2gzehta6eSHzgQ
# 2  {'RestaurantsAttire': "'casual'", 'Alcohol': "...  8nP8ghEpT6WFcM6tfqAaGA
# 3  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...  3C0bnFhjkgYP9mWORKg6cA
# 4  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...  VBVqHnViRLSYAqP7v8iNNQ
#
#                                           categories        city  \
# 0  Food, Ethnic Food, Specialty Food, Restaurants...        Mesa
# 1                 Restaurants, Fish & Chips, Seafood       Tempe
# 2  Ice Cream & Frozen Yogurt, Sandwiches, Food, A...  Scottsdale
# 3        Hot Dogs, Food, Street Vendors, Restaurants   Charlotte
# 4        Mexican, Restaurants, Food, Salad, Desserts  Scottsdale
#
#                                                hours  is_open   latitude  \
# 0  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...        1  33.423705
# 1  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...        1  33.414507
# 2  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  33.493775
# 3  {'Tuesday': '11:0-14:30', 'Wednesday': '11:0-1...        1  35.226911
# 4  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...        1  33.674880
#
#     longitude                 name  postal_code  review_count state  \
# 0 -111.772890          Papaya Thai        85213           130    AZ
# 1 -111.923721  Pete's Fish & Chips        85281           117    AZ
# 2 -111.925933           Sugar Bowl        85251           720    AZ
# 3  -80.843823            Chili Man        28202           172    NC
# 4 -111.888635     Jalapeño Inferno        85255           247    AZ
#
#    business_stars   cuisine
# 0             2.5      thai
# 1             2.0     other
# 2             3.5  american
# 3             5.0     other
# 4             3.5   mexican

# %%
business = business.drop('categories', axis=1)
business.head()
# Out:
#    Unnamed: 0.1               address  \
# 0             0  2706 E University Dr
# 1           139    1017 E Apache Blvd
# 2           258  4005 N Scottsdale Rd
# 3           993               S Tryon
# 4          1174       20825 N Pima Rd
#
#                                           attributes             business_id  \
# 0  {'Caters': 'False', 'OutdoorSeating': 'False',...  j9bWpCRwpDVfwVT_V85qeA
# 1  {'NoiseLevel': "u'average'", 'BusinessAcceptsC...  W7hCuNdn2gzehta6eSHzgQ
# 2  {'RestaurantsAttire': "'casual'", 'Alcohol': "...  8nP8ghEpT6WFcM6tfqAaGA
# 3  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...  3C0bnFhjkgYP9mWORKg6cA
# 4  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...  VBVqHnViRLSYAqP7v8iNNQ
#
#          city                                              hours  is_open  \
# 0        Mesa  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...        1
# 1       Tempe  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...        1
# 2  Scottsdale  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1
# 3   Charlotte  {'Tuesday': '11:0-14:30', 'Wednesday': '11:0-1...        1
# 4  Scottsdale  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...        1
#
#     latitude   longitude                 name  postal_code  review_count  \
# 0  33.423705 -111.772890          Papaya Thai        85213           130
# 1  33.414507 -111.923721  Pete's Fish & Chips        85281           117
# 2  33.493775 -111.925933           Sugar Bowl        85251           720
# 3  35.226911  -80.843823            Chili Man        28202           172
# 4  33.674880 -111.888635     Jalapeño Inferno        85255           247
#
#   state  business_stars   cuisine
# 0    AZ             2.5      thai
# 1    AZ             2.0     other
# 2    AZ             3.5  american
# 3    NC             5.0     other
# 4    AZ             3.5   mexican

# %%
print(f"Total records in business: {business.shape}")
# Out:
# Total records in business: (7390, 15)

# %%
# Take sample from the dask dataframe
sample_biz_df = business.sample(frac=1, replace=False, random_state=42)
sample_biz_df
# Out:
#       Unnamed: 0.1                           address  \
# 7266       3178472         7318 E Shea Blvd, Ste 101
# 3653       1480737                   132 W Church St
# 1539        570412                    1051 W 10th St
# 6071       2595326                  4510 Paradise Rd
# 4165       1698300   3500 Las Vegas Blvd S, Ste R06A
# ...            ...                               ...
# 5191       2160597  4325 E Indian School Rd, Ste 150
# 5226       2180800               3921 E Guadalupe Rd
# 5390       2255517              6430 S McClintock Dr
# 860         302507    6587 Las Vegas Blvd S, Ste 171
# 7270       3179643      6455 S Rainbow Blvd, Ste 101
#
#                                              attributes  \
# 7266  {'HasTV': 'True', 'Alcohol': "u'full_bar'", 'R...
# 3653  {'BYOBCorkage': 'None', 'RestaurantsGoodForGro...
# 1539  {'GoodForKids': 'False', 'RestaurantsAttire': ...
# 6071  {'Caters': 'False', 'BusinessAcceptsCreditCard...
# 4165  {'Smoking': "u'no'", 'RestaurantsGoodForGroups...
# ...                                                 ...
# 5191  {'RestaurantsTakeOut': 'True', 'BikeParking': ...
# 5226  {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 5390  {'Ambience': "{'romantic': False, 'intimate': ...
# 860   {'BusinessParking': "{'garage': False, 'street...
# 7270  {'RestaurantsReservations': 'True', 'WiFi': "u...
#
#                  business_id             city  \
# 7266  8YL_Cm7lYGLfPvp5sseyrQ       Scottsdale
# 3653  0-WocGTpO3Zm4q1Zzz49Rw        Champaign
# 1539  ZLPAP1YKL56ODigLn4wd3w        Cleveland
# 6071  cJWbbvGmyhFiBpG_5hf5LA        Las Vegas
# 4165  uf1Bw8r7f0TFh5drTk_98w        Las Vegas
# ...                      ...              ...
# 5191  Y_9f9tzVRaXjfT9Fa5_W9A          Phoenix
# 5226  TLbx_MR2dyFztoyR5d9H2A          Gilbert
# 5390  ELUUibdDcrZHyvE-e-QsVw            Tempe
# 860   n7V4cD-KqqE3OXk0irJTyA        Las Vegas
# 7270  k-tg18rWRibZ4jKpoqhb0Q  South Las Vegas
#
#                                                   hours  is_open   latitude  \
# 7266  {'Monday': '0:0-0:0', 'Tuesday': '15:0-21:0', ...        0  33.582229
# 3653  {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-2...        1  40.118531
# 1539  {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...        0  41.501009
# 6071  {'Monday': '11:0-16:0', 'Tuesday': '11:0-23:0'...        1  36.107757
# 4165  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...        1  36.118723
# ...                                                 ...      ...        ...
# 5191  {'Monday': '10:45-18:0', 'Tuesday': '10:45-20:...        1  33.494173
# 5226  {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:30',...        1  33.364477
# 5390  {'Monday': '8:30-21:0', 'Tuesday': '11:0-21:0'...        0  33.362505
# 860   {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...        1  36.068236
# 7270  {'Monday': '0:0-0:0', 'Tuesday': '11:30-21:30'...        1  36.071733
#
#        longitude                             name  postal_code  review_count  \
# 7266 -111.923257                   The Grand Blue        85260           131
# 3653  -88.244818                       Sushi Kame        61820           149
# 1539  -81.704360                  The Willeyville        44113           104
# 6071 -115.151691            Hofbräuhaus Las Vegas        89169          1762
# 4165 -115.173435             Smoked Burgers & BBQ        89109           197
# ...          ...                              ...          ...           ...
# 5191 -111.988030                         Uberrito        85018           175
# 5226 -111.706456  Salerno's Restaurant & Pizzeria        85234           230
# 5390 -111.912747              Mac's Broiler & Tap        85283           222
# 860  -115.178633                        GameWorks        89119           556
# 7270 -115.242963           Bonchon - SW Las Vegas        89118           435
#
#      state  business_stars   cuisine
# 7266    AZ             4.0     sushi
# 3653    IL             3.5     sushi
# 1539    OH             4.0  american
# 6071    NV             4.0     other
# 4165    NV             4.5     other
# ...    ...             ...       ...
# 5191    AZ             3.5   mexican
# 5226    AZ             4.0     pizza
# 5390    AZ             3.5  american
# 860     NV             3.5       pub
# 7270    NV             3.5    korean
#
# [7390 rows x 15 columns]

# %% [markdown]
# ## Load `reviews` to Postgres

# %%
rev_url = 'https://tally-ai-dspt3.s3.amazonaws.com/yelp-restaurants/reviews-6-15-20.csv'
rev = load_data(rev_url)
rev.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#   Unnamed: 0               review_id             business_id  reviews_stars  \
# 0          0  Oa-sapLub0wRAzxRKVmtDQ  j9bWpCRwpDVfwVT_V85qeA            5.0
# 1          1  NawvdCkVIvhMO_eMVMdBhw  j9bWpCRwpDVfwVT_V85qeA            3.0
# 2          2  uBWpaM4_PQ1NMB3N9nYkJA  j9bWpCRwpDVfwVT_V85qeA            1.0
# 3          3  EIcE_Xw9G5bDAY-XQ0Vosg  j9bWpCRwpDVfwVT_V85qeA            1.0
# 4          4  BXTxF_ijBmm5RPYELr-5RQ  j9bWpCRwpDVfwVT_V85qeA            4.0
#
#                   date                                               text
# 0  2017-02-23 03:10:38  Best thai food in Mesa, and you get so much fo...
# 1  2010-12-04 00:38:28  There are several contributing factors to the ...
# 2  2012-03-07 21:51:40  Moving to the Phoenix area was a shock to begi...
# 3  2011-10-06 00:29:51  Usually ok but today we went and ordered garde...
# 4  2013-11-20 03:08:02  I have never dined in. The restaurant itself i...

# %%
print(f"Total records in reviews: {rev.shape}")
# Out:
# Total records in reviews: (3244807, 6)

# %%
# Take sample from the dask dataframe
sample_rev_df = rev.sample(frac=.1, replace=False, random_state=42)
sample_rev_df
# Out:
#         Unnamed: 0               review_id             business_id  \
# 1022930    1022929  NTpWt7ZBsztNDaXDaFucRQ  4j0WfdS_lHG9uSH7cd1PFg
# 1958278    1958277  ESy8I_9j84fzPFqKJOs4vg  ABJjxuO6oh5D9R48-eAUdQ
# 2175959    2175958  ebwD3j69KHnrf_9VUUfZPg  L7txS44bvz862djgTOim9w
# 2865950    2865949  pDeQbN2eUkhsk9Lpd9hAuw  dThrFTK_bqo1woPvUgY70g
# 2228976    2228975  staVQafNxH_ZARsA7HKfrQ  iCQpiavjjPzJ5_3gPD5Ebg
# ...            ...                     ...                     ...
# 2881535    2881534  ZU03Yp4no5RyIIpqlu-1VQ  K7fip0nDFFdCC7OCnNOotQ
# 567780      567779  hyCijMm5vIjqmA4ic27ANw  frwKRRIIR0QMv25IKVDIMA
# 2863659    2863658  B8T4jfPt3dSi8zzD4DK34w  -bMZCfTK7fxFaURynKpBMA
# 3229469    3229468  r105P8nDMptOb_rqTX7k_Q  LtXy1VinKWfuLFslVarKRw
# 3017671    3017670  jZ6g9DVcanx6PHQi35_Ygw  7d7pZlKji6NozhHP1SrVqw
#
#          reviews_stars                 date  \
# 1022930            4.0  2019-06-24 03:09:01
# 1958278            5.0  2017-08-07 05:26:21
# 2175959            3.0  2016-05-22 04:17:07
# 2865950            5.0  2016-12-16 02:12:15
# 2228976            5.0  2012-03-16 07:59:07
# ...                ...                  ...
# 2881535            4.0  2013-10-23 15:02:51
# 567780             4.0  2014-12-18 18:48:52
# 2863659            1.0  2019-03-19 03:32:30
# 3229469            5.0  2019-01-20 10:16:18
# 3017671            4.0  2016-06-16 04:00:13
#
#                                                       text
# 1022930  Ordered via Postmates; this was our first time...
# 1958278  I went to the buffet in the afternoon on Satur...
# 2175959  I was fairly hungry so I opted for a few items...
# 2865950  We loved Pomelo!  The burger, the pizza and ri...
# 2228976  By far one of the best tasting pizzas ever!! I...
# ...                                                    ...
# 2881535  I went to Hyde as part of a huge bachelorette ...
# 567780   Delicious! I've only been there a couple of ti...
# 2863659  Will never return to this restaurant again! I'...
# 3229469  I love Fat burger. it's a must every time I vi...
# 3017671  If you want feel good food that you don't feel...
#
# [324481 rows x 6 columns]

# %% [markdown]
# # Setup SQL Alchemy, Create Tables and DB Models

# %% [markdown]
# Resources:
#
# https://towardsdatascience.com/sqlalchemy-python-tutorial-79a577141a91
#
# https://www.youtube.com/watch?v=OT5qJBINiJY

# %%
from sqlalchemy.orm import relationship
from sqlalchemy import (
    Column,
    Integer,
    String,
    ForeignKey,
    DateTime,
    Float,
    Text,
    Boolean,
    UniqueConstraint,
    ForeignKeyConstraint,
)
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
import sqlalchemy as db

URI = 'postgres://tallyadmin:Tally_123456@tally-ai.cmfe7iubg1ts.us-east-1.rds.amazonaws.com:5432/tally'

Base = declarative_base()

### Helper Functions ##

def to_dict(inst, cls):
    """
    Convert the sql alchemy query result to a clean python dictionary.
    """
    convert = dict()
    # add your coversions for things like datetime's
    # and what-not that aren't serializable.
    d = dict()
    for c in cls.__table__.columns:
        v = getattr(inst, c.name)
        if c.type in convert.keys() and v is not None:
            try:
                d[c.name] = convert[c.type](v)
            except:
                d[c.name] = "Error:  Failed to covert using ", str(
                    convert[c.type])
        elif v is None:
            d[c.name] = str()
        else:
            d[c.name] = v
    return d

###########################
### Business Data Model ###
###########################


class Business(Base):
    __tablename__ = 'business'
    _class_name = 'Business'

    business_id	 = Column("business_id", String, primary_key=True)
    name = Column("name", String)
    address	= Column("address", String)
    city = Column("city", String)
    zipcode = Column("zipcode", String)
    latitude = Column("latitude", Float)
    longitude = Column("longitude", Float)
    attributes = Column("attributes", String)
    cuisine= Column("cuisine", String)
    review_count = Column("review_count", Integer)
    business_stars = Column("business_stars", Float)
    
    @property
    def json(self):
        return to_dict(self, self.__class__)


###########################
### Reviews Data Model ###
###########################


class Reviews(Base):
    __tablename__ = 'reviews'
    _class_name = 'Reviews'

    review_id = Column("review_id", String, primary_key=True)
    business_id	 = Column("business_id", String)
    reviews_stars = Column("reviews_stars", Float)
    datetime = Column("datetime", String)
    text = Column("text", Text)
    
    @property
    def json(self):
        return to_dict(self, self.__class__)

# DS Schema
dbschema = "tallyds"
engine = db.create_engine(URI,connect_args={'options': '-csearch_path={}'.format(dbschema)})

# Drop tables before creating new ones
Base.metadata.drop_all(bind=engine)

# Create new tables
Base.metadata.create_all(bind=engine)

# Create Session and attach db connection to it
Session = sessionmaker(bind=engine)

# %% [markdown]
# ### 1. Insert records to `business` table in Postgres

# %%
# Loop through each row of dask dataframe and insert into business table
session = Session()
count = 0
for row in business.itertuples():
    biz = Business()
    biz.business_id = row.business_id
    biz.name = row.name
    biz.address = row.address
    biz.city = row.city
    biz.zipcode = row.postal_code
    biz.latitude = row.latitude
    biz.longitude = row.longitude
    biz.attributes = row.attributes
    biz.cuisine = row.cuisine
    biz.review_count = row.review_count
    biz.business_stars = row.business_stars
    session.add(biz)
    count += 1
    if count % 500 == 0:
        print(f"Inserted {count} records so far...")
        session.commit()
session.commit()
session.close()
# Out:
# Inserted 500 records so far...
# Inserted 1000 records so far...
# Inserted 1500 records so far...
# Inserted 2000 records so far...
# Inserted 2500 records so far...
# Inserted 3000 records so far...
# Inserted 3500 records so far...
# Inserted 4000 records so far...
# Inserted 4500 records so far...
# Inserted 5000 records so far...
# Inserted 5500 records so far...
# Inserted 6000 records so far...
# Inserted 6500 records so far...
# Inserted 7000 records so far...

# %% [markdown]
# ### 2. Insert records to `reviews` table in Postgres

# %%
# Loop through each row of dask dataframe and insert into review table
session = Session()
count = 0
for row in rev.itertuples():
    rev = Reviews()
    rev.review_id = row.review_id
    rev.business_id = row.business_id
    rev.reviews_stars = row.reviews_stars
    rev.datetime = row.date
    rev.text = row.text
    session.add(rev)
    count += 1
    if count % 500 == 0:
        print(f"Inserted {count} records so far...")
        session.commit()
session.commit()
session.close()
# Out:
# Inserted 500 records so far...
# Inserted 1000 records so far...
# Inserted 1500 records so far...
# Inserted 2000 records so far...
# Inserted 2500 records so far...
# Inserted 3000 records so far...
# Inserted 3500 records so far...
# Inserted 4000 records so far...
# Inserted 4500 records so far...
# Inserted 5000 records so far...
# Inserted 5500 records so far...
# Inserted 6000 records so far...
# Inserted 6500 records so far...
# Inserted 7000 records so far...
# Inserted 7500 records so far...
# Inserted 8000 records so far...
# Inserted 8500 records so far...
# Inserted 9000 records so far...
# Inserted 9500 records so far...
# Inserted 10000 records so far...
# Inserted 10500 records so far...
# Inserted 11000 records so far...
# Inserted 11500 records so far...
# Inserted 12000 records so far...
# Inserted 12500 records so far...
# Inserted 13000 records so far...
# Inserted 13500 records so far...
# Inserted 14000 records so far...
# Inserted 14500 records so far...
# Inserted 15000 records so far...
# Inserted 15500 records so far...
# Inserted 16000 records so far...
# Inserted 16500 records so far...
# Inserted 17000 records so far...
# Inserted 17500 records so far...
# Inserted 18000 records so far...
# Inserted 18500 records so far...
# Inserted 19000 records so far...
# Inserted 19500 records so far...
# Inserted 20000 records so far...
# Inserted 20500 records so far...
# Inserted 21000 records so far...
# Inserted 21500 records so far...
# Inserted 22000 records so far...
# Inserted 22500 records so far...
# Inserted 23000 records so far...
# Inserted 23500 records so far...
# Inserted 24000 records so far...
# Inserted 24500 records so far...
# Inserted 25000 records so far...
# Inserted 25500 records so far...
# Inserted 26000 records so far...
# Inserted 26500 records so far...
# Inserted 27000 records so far...
# Inserted 27500 records so far...
# Inserted 28000 records so far...
# Inserted 28500 records so far...
# Inserted 29000 records so far...
# Inserted 29500 records so far...
# Inserted 30000 records so far...
# Inserted 30500 records so far...
# Inserted 31000 records so far...
# Inserted 31500 records so far...
# Inserted 32000 records so far...
# Inserted 32500 records so far...
# Inserted 33000 records so far...
# Inserted 33500 records so far...
# Inserted 34000 records so far...
# Inserted 34500 records so far...
# Inserted 35000 records so far...
# Inserted 35500 records so far...
# Inserted 36000 records so far...
# Inserted 36500 records so far...
# Inserted 37000 records so far...
# Inserted 37500 records so far...
# Inserted 38000 records so far...
# Inserted 38500 records so far...
# Inserted 39000 records so far...
# Inserted 39500 records so far...
# Inserted 40000 records so far...
# Inserted 40500 records so far...
# Inserted 41000 records so far...
# Inserted 41500 records so far...
# Inserted 42000 records so far...
# Inserted 42500 records so far...
# Inserted 43000 records so far...
# Inserted 43500 records so far...
# Inserted 44000 records so far...
# Inserted 44500 records so far...
# Inserted 45000 records so far...
# Inserted 45500 records so far...
# Inserted 46000 records so far...
# Inserted 46500 records so far...
# Inserted 47000 records so far...
# Inserted 47500 records so far...
# Inserted 48000 records so far...
# Inserted 48500 records so far...
# Inserted 49000 records so far...
# Inserted 49500 records so far...
# Inserted 50000 records so far...
# Inserted 50500 records so far...
# Inserted 51000 records so far...
# Inserted 51500 records so far...
# Inserted 52000 records so far...
# Inserted 52500 records so far...
# Inserted 53000 records so far...
# Inserted 53500 records so far...
# Inserted 54000 records so far...
# Inserted 54500 records so far...
# Inserted 55000 records so far...
# Inserted 55500 records so far...
# Inserted 56000 records so far...
# Inserted 56500 records so far...
# Inserted 57000 records so far...
# Inserted 57500 records so far...
# Inserted 58000 records so far...
# Inserted 58500 records so far...
# Inserted 59000 records so far...
# Inserted 59500 records so far...
# Inserted 60000 records so far...
# Inserted 60500 records so far...
# Inserted 61000 records so far...
# Inserted 61500 records so far...
# Inserted 62000 records so far...
# Inserted 62500 records so far...
# Inserted 63000 records so far...
# Inserted 63500 records so far...
# Inserted 64000 records so far...
# Inserted 64500 records so far...
# Inserted 65000 records so far...
# Inserted 65500 records so far...
# Inserted 66000 records so far...
# Inserted 66500 records so far...
# Inserted 67000 records so far...
# Inserted 67500 records so far...
# Inserted 68000 records so far...
# Inserted 68500 records so far...
# Inserted 69000 records so far...
# Inserted 69500 records so far...
# Inserted 70000 records so far...
# Inserted 70500 records so far...
# Inserted 71000 records so far...
# Inserted 71500 records so far...
# Inserted 72000 records so far...
# Inserted 72500 records so far...
# Inserted 73000 records so far...
# Inserted 73500 records so far...
# Inserted 74000 records so far...
# Inserted 74500 records so far...
# Inserted 75000 records so far...
# Inserted 75500 records so far...
# Inserted 76000 records so far...
# Inserted 76500 records so far...
# Inserted 77000 records so far...
# Inserted 77500 records so far...
# Inserted 78000 records so far...
# Inserted 78500 records so far...
# Inserted 79000 records so far...
# Inserted 79500 records so far...
# Inserted 80000 records so far...
# Inserted 80500 records so far...
# Inserted 81000 records so far...
# Inserted 81500 records so far...
# Inserted 82000 records so far...
# Inserted 82500 records so far...
# Inserted 83000 records so far...
# Inserted 83500 records so far...
# Inserted 84000 records so far...
# Inserted 84500 records so far...
# Inserted 85000 records so far...
# Inserted 85500 records so far...
# Inserted 86000 records so far...
# Inserted 86500 records so far...
# Inserted 87000 records so far...
# Inserted 87500 records so far...
# Inserted 88000 records so far...
# Inserted 88500 records so far...
# Inserted 89000 records so far...
# Inserted 89500 records so far...
# Inserted 90000 records so far...
# Inserted 90500 records so far...
# Inserted 91000 records so far...
# Inserted 91500 records so far...
# Inserted 92000 records so far...
# Inserted 92500 records so far...
# Inserted 93000 records so far...
# Inserted 93500 records so far...
# Inserted 94000 records so far...
# Inserted 94500 records so far...
# Inserted 95000 records so far...
# Inserted 95500 records so far...
# Inserted 96000 records so far...
# Inserted 96500 records so far...
# Inserted 97000 records so far...
# Inserted 97500 records so far...
# Inserted 98000 records so far...
# Inserted 98500 records so far...
# Inserted 99000 records so far...
# Inserted 99500 records so far...
# Inserted 100000 records so far...
# Inserted 100500 records so far...
# Inserted 101000 records so far...
# Inserted 101500 records so far...
# Inserted 102000 records so far...
# Inserted 102500 records so far...
# Inserted 103000 records so far...
# Inserted 103500 records so far...
# Inserted 104000 records so far...
# Inserted 104500 records so far...
# Inserted 105000 records so far...
# Inserted 105500 records so far...
# Inserted 106000 records so far...
# Inserted 106500 records so far...
# Inserted 107000 records so far...
# Inserted 107500 records so far...
# Inserted 108000 records so far...
# Inserted 108500 records so far...
# Inserted 109000 records so far...
# Inserted 109500 records so far...
# Inserted 110000 records so far...
# Inserted 110500 records so far...
# Inserted 111000 records so far...
# Inserted 111500 records so far...
# Inserted 112000 records so far...
# Inserted 112500 records so far...
# Inserted 113000 records so far...
# Inserted 113500 records so far...
# Inserted 114000 records so far...
# Inserted 114500 records so far...
# Inserted 115000 records so far...
# Inserted 115500 records so far...
# Inserted 116000 records so far...
# Inserted 116500 records so far...
# Inserted 117000 records so far...
# Inserted 117500 records so far...
# Inserted 118000 records so far...
# Inserted 118500 records so far...
# Inserted 119000 records so far...
# Inserted 119500 records so far...
# Inserted 120000 records so far...
# Inserted 120500 records so far...
# Inserted 121000 records so far...
# Inserted 121500 records so far...
# Inserted 122000 records so far...
# Inserted 122500 records so far...
# Inserted 123000 records so far...
# Inserted 123500 records so far...
# Inserted 124000 records so far...
# Inserted 124500 records so far...
# Inserted 125000 records so far...
# Inserted 125500 records so far...
# Inserted 126000 records so far...
# Inserted 126500 records so far...
# Inserted 127000 records so far...
# Inserted 127500 records so far...
# Inserted 128000 records so far...
# Inserted 128500 records so far...
# Inserted 129000 records so far...
# Inserted 129500 records so far...
# Inserted 130000 records so far...
# Inserted 130500 records so far...
# Inserted 131000 records so far...
# Inserted 131500 records so far...
# Inserted 132000 records so far...
# Inserted 132500 records so far...
# Inserted 133000 records so far...
# Inserted 133500 records so far...
# Inserted 134000 records so far...
# Inserted 134500 records so far...
# Inserted 135000 records so far...
# Inserted 135500 records so far...
# Inserted 136000 records so far...
# Inserted 136500 records so far...
# Inserted 137000 records so far...
# Inserted 137500 records so far...
# Inserted 138000 records so far...
# Inserted 138500 records so far...
# Inserted 139000 records so far...
# Inserted 139500 records so far...
# Inserted 140000 records so far...
# Inserted 140500 records so far...
# Inserted 141000 records so far...
# Inserted 141500 records so far...
# Inserted 142000 records so far...
# Inserted 142500 records so far...
# Inserted 143000 records so far...
# Inserted 143500 records so far...
# Inserted 144000 records so far...
# Inserted 144500 records so far...
# Inserted 145000 records so far...
# Inserted 145500 records so far...
# Inserted 146000 records so far...
# Inserted 146500 records so far...
# Inserted 147000 records so far...
# Inserted 147500 records so far...
# Inserted 148000 records so far...
# Inserted 148500 records so far...
# Inserted 149000 records so far...
# Inserted 149500 records so far...
# Inserted 150000 records so far...
# Inserted 150500 records so far...
# Inserted 151000 records so far...
# Inserted 151500 records so far...
# Inserted 152000 records so far...
# Inserted 152500 records so far...
# Inserted 153000 records so far...
# Inserted 153500 records so far...
# Inserted 154000 records so far...
# Inserted 154500 records so far...
# Inserted 155000 records so far...
# Inserted 155500 records so far...
# Inserted 156000 records so far...
# Inserted 156500 records so far...
# Inserted 157000 records so far...
# Inserted 157500 records so far...
# Inserted 158000 records so far...
# Inserted 158500 records so far...
# Inserted 159000 records so far...
# Inserted 159500 records so far...
# Inserted 160000 records so far...
# Inserted 160500 records so far...
# Inserted 161000 records so far...
# Inserted 161500 records so far...
# Inserted 162000 records so far...
# Inserted 162500 records so far...
# Inserted 163000 records so far...
# Inserted 163500 records so far...
# Inserted 164000 records so far...
# Inserted 164500 records so far...
# Inserted 165000 records so far...
# Inserted 165500 records so far...
# Inserted 166000 records so far...
# Inserted 166500 records so far...
# Inserted 167000 records so far...
# Inserted 167500 records so far...
# Inserted 168000 records so far...
# Inserted 168500 records so far...
# Inserted 169000 records so far...
# Inserted 169500 records so far...
# Inserted 170000 records so far...
# Inserted 170500 records so far...
# Inserted 171000 records so far...
# Inserted 171500 records so far...
# Inserted 172000 records so far...
# Inserted 172500 records so far...
# Inserted 173000 records so far...
# Inserted 173500 records so far...
# Inserted 174000 records so far...
# Inserted 174500 records so far...
# Inserted 175000 records so far...
# Inserted 175500 records so far...
# Inserted 176000 records so far...
# Inserted 176500 records so far...
# Inserted 177000 records so far...
# Inserted 177500 records so far...
# Inserted 178000 records so far...
# Inserted 178500 records so far...
# Inserted 179000 records so far...
# Inserted 179500 records so far...
# Inserted 180000 records so far...
# Inserted 180500 records so far...
# Inserted 181000 records so far...
# Inserted 181500 records so far...
# Inserted 182000 records so far...
# Inserted 182500 records so far...
# Inserted 183000 records so far...
# Inserted 183500 records so far...
# Inserted 184000 records so far...
# Inserted 184500 records so far...
# Inserted 185000 records so far...
# Inserted 185500 records so far...
# Inserted 186000 records so far...
# Inserted 186500 records so far...
# Inserted 187000 records so far...
# Inserted 187500 records so far...
# Inserted 188000 records so far...
# Inserted 188500 records so far...
# Inserted 189000 records so far...
# Inserted 189500 records so far...
# Inserted 190000 records so far...
# Inserted 190500 records so far...
# Inserted 191000 records so far...
# Inserted 191500 records so far...
# Inserted 192000 records so far...
# Inserted 192500 records so far...
# Inserted 193000 records so far...
# Inserted 193500 records so far...
# Inserted 194000 records so far...
# Inserted 194500 records so far...
# Inserted 195000 records so far...
# Inserted 195500 records so far...
# Inserted 196000 records so far...
# Inserted 196500 records so far...
# Inserted 197000 records so far...
# Inserted 197500 records so far...
# Inserted 198000 records so far...
# Inserted 198500 records so far...
# Inserted 199000 records so far...
# Inserted 199500 records so far...
# Inserted 200000 records so far...
# Inserted 200500 records so far...
# Inserted 201000 records so far...
# Inserted 201500 records so far...
# Inserted 202000 records so far...
# Inserted 202500 records so far...
# Inserted 203000 records so far...
# Inserted 203500 records so far...
# Inserted 204000 records so far...
# Inserted 204500 records so far...
# Inserted 205000 records so far...
# Inserted 205500 records so far...
# Inserted 206000 records so far...
# Inserted 206500 records so far...
# Inserted 207000 records so far...
# Inserted 207500 records so far...
# Inserted 208000 records so far...
# Inserted 208500 records so far...
# Inserted 209000 records so far...
# Inserted 209500 records so far...
# Inserted 210000 records so far...
# Inserted 210500 records so far...
# Inserted 211000 records so far...
# Inserted 211500 records so far...
# Inserted 212000 records so far...
# Inserted 212500 records so far...
# Inserted 213000 records so far...
# Inserted 213500 records so far...
# Inserted 214000 records so far...
# Inserted 214500 records so far...
# Inserted 215000 records so far...
# Inserted 215500 records so far...
# Inserted 216000 records so far...
# Inserted 216500 records so far...
# Inserted 217000 records so far...
# Inserted 217500 records so far...
# Inserted 218000 records so far...
# Inserted 218500 records so far...
# Inserted 219000 records so far...
# Inserted 219500 records so far...
# Inserted 220000 records so far...
# Inserted 220500 records so far...
# Inserted 221000 records so far...
# Inserted 221500 records so far...
# Inserted 222000 records so far...
# Inserted 222500 records so far...
# Inserted 223000 records so far...
# Inserted 223500 records so far...
# Inserted 224000 records so far...
# Inserted 224500 records so far...
# Inserted 225000 records so far...
# Inserted 225500 records so far...
# Inserted 226000 records so far...
# Inserted 226500 records so far...
# Inserted 227000 records so far...
# Inserted 227500 records so far...
# Inserted 228000 records so far...
# Inserted 228500 records so far...
# Inserted 229000 records so far...
# Inserted 229500 records so far...
# Inserted 230000 records so far...
# Inserted 230500 records so far...
# Inserted 231000 records so far...
# Inserted 231500 records so far...
# Inserted 232000 records so far...
# Inserted 232500 records so far...
# Inserted 233000 records so far...
# Inserted 233500 records so far...
# Inserted 234000 records so far...
# Inserted 234500 records so far...
# Inserted 235000 records so far...
# Inserted 235500 records so far...
# Inserted 236000 records so far...
# Inserted 236500 records so far...
# Inserted 237000 records so far...
# Inserted 237500 records so far...
# Inserted 238000 records so far...
# Inserted 238500 records so far...
# Inserted 239000 records so far...
# Inserted 239500 records so far...
# Inserted 240000 records so far...
# Inserted 240500 records so far...
# Inserted 241000 records so far...
# Inserted 241500 records so far...
# Inserted 242000 records so far...
# Inserted 242500 records so far...
# Inserted 243000 records so far...
# Inserted 243500 records so far...
# Inserted 244000 records so far...
# Inserted 244500 records so far...
# Inserted 245000 records so far...
# Inserted 245500 records so far...
# Inserted 246000 records so far...
# Inserted 246500 records so far...
# Inserted 247000 records so far...
# Inserted 247500 records so far...
# Inserted 248000 records so far...
# Inserted 248500 records so far...
# Inserted 249000 records so far...
# Inserted 249500 records so far...
# Inserted 250000 records so far...
# Inserted 250500 records so far...
# Inserted 251000 records so far...
# Inserted 251500 records so far...
# Inserted 252000 records so far...
# Inserted 252500 records so far...
# Inserted 253000 records so far...
# Inserted 253500 records so far...
# Inserted 254000 records so far...
# Inserted 254500 records so far...
# Inserted 255000 records so far...
# Inserted 255500 records so far...
# Inserted 256000 records so far...
# Inserted 256500 records so far...
# Inserted 257000 records so far...
# Inserted 257500 records so far...
# Inserted 258000 records so far...
# Inserted 258500 records so far...
# Inserted 259000 records so far...
# Inserted 259500 records so far...
# Inserted 260000 records so far...
# Inserted 260500 records so far...
# Inserted 261000 records so far...
# Inserted 261500 records so far...
# Inserted 262000 records so far...
# Inserted 262500 records so far...
# Inserted 263000 records so far...
# Inserted 263500 records so far...
# Inserted 264000 records so far...
# Inserted 264500 records so far...
# Inserted 265000 records so far...
# Inserted 265500 records so far...
# Inserted 266000 records so far...
# Inserted 266500 records so far...
# Inserted 267000 records so far...
# Inserted 267500 records so far...
# Inserted 268000 records so far...
# Inserted 268500 records so far...
# Inserted 269000 records so far...
# Inserted 269500 records so far...
# Inserted 270000 records so far...
# Inserted 270500 records so far...
# Inserted 271000 records so far...
# Inserted 271500 records so far...
# Inserted 272000 records so far...
# Inserted 272500 records so far...
# Inserted 273000 records so far...
# Inserted 273500 records so far...
# Inserted 274000 records so far...
# Inserted 274500 records so far...
# Inserted 275000 records so far...
# Inserted 275500 records so far...
# Inserted 276000 records so far...
# Inserted 276500 records so far...
# Inserted 277000 records so far...
# Inserted 277500 records so far...
# Inserted 278000 records so far...
# Inserted 278500 records so far...
# Inserted 279000 records so far...
# Inserted 279500 records so far...
# Inserted 280000 records so far...
# Inserted 280500 records so far...
# Inserted 281000 records so far...
# Inserted 281500 records so far...
# Inserted 282000 records so far...
# Inserted 282500 records so far...
# Inserted 283000 records so far...
# Inserted 283500 records so far...
# Inserted 284000 records so far...
# Inserted 284500 records so far...
# Inserted 285000 records so far...
# Inserted 285500 records so far...
# Inserted 286000 records so far...
# Inserted 286500 records so far...
# Inserted 287000 records so far...
# Inserted 287500 records so far...
# Inserted 288000 records so far...
# Inserted 288500 records so far...
# Inserted 289000 records so far...
# Inserted 289500 records so far...
# Inserted 290000 records so far...
# Inserted 290500 records so far...
# Inserted 291000 records so far...
# Inserted 291500 records so far...
# Inserted 292000 records so far...
# Inserted 292500 records so far...
# Inserted 293000 records so far...
# Inserted 293500 records so far...
# Inserted 294000 records so far...
# Inserted 294500 records so far...
# Inserted 295000 records so far...
# Inserted 295500 records so far...
# Inserted 296000 records so far...
# Inserted 296500 records so far...
# Inserted 297000 records so far...
# Inserted 297500 records so far...
# Inserted 298000 records so far...
# Inserted 298500 records so far...
# Inserted 299000 records so far...
# Inserted 299500 records so far...
# Inserted 300000 records so far...
# Inserted 300500 records so far...
# Inserted 301000 records so far...
# Inserted 301500 records so far...
# Inserted 302000 records so far...
# Inserted 302500 records so far...
# Inserted 303000 records so far...
# Inserted 303500 records so far...
# Inserted 304000 records so far...
# Inserted 304500 records so far...
# Inserted 305000 records so far...
# Inserted 305500 records so far...
# Inserted 306000 records so far...
# Inserted 306500 records so far...
# Inserted 307000 records so far...
# Inserted 307500 records so far...
# Inserted 308000 records so far...
# Inserted 308500 records so far...
# Inserted 309000 records so far...
# Inserted 309500 records so far...
# Inserted 310000 records so far...
# Inserted 310500 records so far...
# Inserted 311000 records so far...
# Inserted 311500 records so far...
# Inserted 312000 records so far...
# Inserted 312500 records so far...
# Inserted 313000 records so far...
# Inserted 313500 records so far...
# Inserted 314000 records so far...
# Inserted 314500 records so far...
# Inserted 315000 records so far...
# Inserted 315500 records so far...
# Inserted 316000 records so far...
# Inserted 316500 records so far...
# Inserted 317000 records so far...
# Inserted 317500 records so far...
# Inserted 318000 records so far...
# Inserted 318500 records so far...
# Inserted 319000 records so far...
# Inserted 319500 records so far...
# Inserted 320000 records so far...
# Inserted 320500 records so far...
# Inserted 321000 records so far...
# Inserted 321500 records so far...
# Inserted 322000 records so far...
# Inserted 322500 records so far...
# Inserted 323000 records so far...
# Inserted 323500 records so far...
# Inserted 324000 records so far...
# Inserted 324500 records so far...
# Inserted 325000 records so far...
# Inserted 325500 records so far...
# Inserted 326000 records so far...
# Inserted 326500 records so far...
# Inserted 327000 records so far...
# Inserted 327500 records so far...
# Inserted 328000 records so far...
# Inserted 328500 records so far...
# Inserted 329000 records so far...
# Inserted 329500 records so far...
# Inserted 330000 records so far...
# Inserted 330500 records so far...
# Inserted 331000 records so far...
# Inserted 331500 records so far...
# Inserted 332000 records so far...
# Inserted 332500 records so far...
# Inserted 333000 records so far...
# Inserted 333500 records so far...
# Inserted 334000 records so far...
# Inserted 334500 records so far...
# Inserted 335000 records so far...
# Inserted 335500 records so far...
# Inserted 336000 records so far...
# Inserted 336500 records so far...
# Inserted 337000 records so far...
# Inserted 337500 records so far...
# Inserted 338000 records so far...
# Inserted 338500 records so far...
# Inserted 339000 records so far...
# Inserted 339500 records so far...
# Inserted 340000 records so far...
# Inserted 340500 records so far...
# Inserted 341000 records so far...
# Inserted 341500 records so far...
# Inserted 342000 records so far...
# Inserted 342500 records so far...
# Inserted 343000 records so far...
# Inserted 343500 records so far...
# Inserted 344000 records so far...
# Inserted 344500 records so far...
# Inserted 345000 records so far...
# Inserted 345500 records so far...
# Inserted 346000 records so far...
# Inserted 346500 records so far...
# Inserted 347000 records so far...
# Inserted 347500 records so far...
# Inserted 348000 records so far...
# Inserted 348500 records so far...
# Inserted 349000 records so far...
# Inserted 349500 records so far...
# Inserted 350000 records so far...
# Inserted 350500 records so far...
# Inserted 351000 records so far...
# Inserted 351500 records so far...
# Inserted 352000 records so far...
# Inserted 352500 records so far...
# Inserted 353000 records so far...
# Inserted 353500 records so far...
# Inserted 354000 records so far...
# Inserted 354500 records so far...
# Inserted 355000 records so far...
# Inserted 355500 records so far...
# Inserted 356000 records so far...
# Inserted 356500 records so far...
# Inserted 357000 records so far...
# Inserted 357500 records so far...
# Inserted 358000 records so far...
# Inserted 358500 records so far...
# Inserted 359000 records so far...
# Inserted 359500 records so far...
# Inserted 360000 records so far...
# Inserted 360500 records so far...
# Inserted 361000 records so far...
# Inserted 361500 records so far...
# Inserted 362000 records so far...
# Inserted 362500 records so far...
# Inserted 363000 records so far...
# Inserted 363500 records so far...
# Inserted 364000 records so far...
# Inserted 364500 records so far...
# Inserted 365000 records so far...
# Inserted 365500 records so far...
# Inserted 366000 records so far...
# Inserted 366500 records so far...
# Inserted 367000 records so far...
# Inserted 367500 records so far...
# Inserted 368000 records so far...
# Inserted 368500 records so far...
# Inserted 369000 records so far...
# Inserted 369500 records so far...
# Inserted 370000 records so far...
# Inserted 370500 records so far...
# Inserted 371000 records so far...
# Inserted 371500 records so far...
# Inserted 372000 records so far...
# Inserted 372500 records so far...
# Inserted 373000 records so far...
# Inserted 373500 records so far...
# Inserted 374000 records so far...
# Inserted 374500 records so far...
# Inserted 375000 records so far...
# Inserted 375500 records so far...
# Inserted 376000 records so far...
# Inserted 376500 records so far...
# Inserted 377000 records so far...
# Inserted 377500 records so far...
# Inserted 378000 records so far...
# Inserted 378500 records so far...
# Inserted 379000 records so far...
# Inserted 379500 records so far...
# Inserted 380000 records so far...
# Inserted 380500 records so far...
# Inserted 381000 records so far...
# Inserted 381500 records so far...
# Inserted 382000 records so far...
# Inserted 382500 records so far...
# Inserted 383000 records so far...
# Inserted 383500 records so far...
# Inserted 384000 records so far...
# Inserted 384500 records so far...
# Inserted 385000 records so far...
# Inserted 385500 records so far...
# Inserted 386000 records so far...
# Inserted 386500 records so far...
# Inserted 387000 records so far...
# Inserted 387500 records so far...
# Inserted 388000 records so far...
# Inserted 388500 records so far...
# Inserted 389000 records so far...
# Inserted 389500 records so far...
# Inserted 390000 records so far...
# Inserted 390500 records so far...
# Inserted 391000 records so far...
# Inserted 391500 records so far...
# Inserted 392000 records so far...
# Inserted 392500 records so far...
# Inserted 393000 records so far...
# Inserted 393500 records so far...
# Inserted 394000 records so far...
# Inserted 394500 records so far...
# Inserted 395000 records so far...
# Inserted 395500 records so far...
# Inserted 396000 records so far...
# Inserted 396500 records so far...
# Inserted 397000 records so far...
# Inserted 397500 records so far...
# Inserted 398000 records so far...
# Inserted 398500 records so far...
# Inserted 399000 records so far...
# Inserted 399500 records so far...
# Inserted 400000 records so far...
# Inserted 400500 records so far...
# Inserted 401000 records so far...
# Inserted 401500 records so far...
# Inserted 402000 records so far...
# Inserted 402500 records so far...
# Inserted 403000 records so far...
# Inserted 403500 records so far...
# Inserted 404000 records so far...
# Inserted 404500 records so far...
# Inserted 405000 records so far...
# Inserted 405500 records so far...
# Inserted 406000 records so far...
# Inserted 406500 records so far...
# Inserted 407000 records so far...
# Inserted 407500 records so far...
# Inserted 408000 records so far...
# Inserted 408500 records so far...
# Inserted 409000 records so far...
# Inserted 409500 records so far...
# Inserted 410000 records so far...
# Inserted 410500 records so far...
# Inserted 411000 records so far...
# Inserted 411500 records so far...
# Inserted 412000 records so far...
# Inserted 412500 records so far...
# Inserted 413000 records so far...
# Inserted 413500 records so far...
# Inserted 414000 records so far...
# Inserted 414500 records so far...
# Inserted 415000 records so far...
# Inserted 415500 records so far...
# Inserted 416000 records so far...
# Inserted 416500 records so far...
# Inserted 417000 records so far...
# Inserted 417500 records so far...
# Inserted 418000 records so far...
# Inserted 418500 records so far...
# Inserted 419000 records so far...
# Inserted 419500 records so far...
# Inserted 420000 records so far...
# Inserted 420500 records so far...
# Inserted 421000 records so far...
# Inserted 421500 records so far...
# Inserted 422000 records so far...
# Inserted 422500 records so far...
# Inserted 423000 records so far...
# Inserted 423500 records so far...
# Inserted 424000 records so far...
# Inserted 424500 records so far...
# Inserted 425000 records so far...
# Inserted 425500 records so far...
# Inserted 426000 records so far...
# Inserted 426500 records so far...
# Inserted 427000 records so far...
# Inserted 427500 records so far...
# Inserted 428000 records so far...
# Inserted 428500 records so far...
# Inserted 429000 records so far...
# Inserted 429500 records so far...
# Inserted 430000 records so far...
# Inserted 430500 records so far...
# Inserted 431000 records so far...
# Inserted 431500 records so far...
# Inserted 432000 records so far...
# Inserted 432500 records so far...
# Inserted 433000 records so far...
# Inserted 433500 records so far...
# Inserted 434000 records so far...
# Inserted 434500 records so far...
# Inserted 435000 records so far...
# Inserted 435500 records so far...
# Inserted 436000 records so far...
# Inserted 436500 records so far...
# Inserted 437000 records so far...
# Inserted 437500 records so far...
# Inserted 438000 records so far...
# Inserted 438500 records so far...
# Inserted 439000 records so far...
# Inserted 439500 records so far...
# Inserted 440000 records so far...
# Inserted 440500 records so far...
# Inserted 441000 records so far...
# Inserted 441500 records so far...
# Inserted 442000 records so far...
# Inserted 442500 records so far...
# Inserted 443000 records so far...
# Inserted 443500 records so far...
# Inserted 444000 records so far...
# Inserted 444500 records so far...
# Inserted 445000 records so far...
# Inserted 445500 records so far...
# Inserted 446000 records so far...
# Inserted 446500 records so far...
# Inserted 447000 records so far...
# Inserted 447500 records so far...
# Inserted 448000 records so far...
# Inserted 448500 records so far...
# Inserted 449000 records so far...
# Inserted 449500 records so far...
# Inserted 450000 records so far...
# Inserted 450500 records so far...
# Inserted 451000 records so far...
# Inserted 451500 records so far...
# Inserted 452000 records so far...
# Inserted 452500 records so far...
# Inserted 453000 records so far...
# Inserted 453500 records so far...
# Inserted 454000 records so far...
# Inserted 454500 records so far...
# Inserted 455000 records so far...
# Inserted 455500 records so far...
# Inserted 456000 records so far...
# Inserted 456500 records so far...
# Inserted 457000 records so far...
# Inserted 457500 records so far...
# Inserted 458000 records so far...
# Inserted 458500 records so far...
# Inserted 459000 records so far...
# Inserted 459500 records so far...
# Inserted 460000 records so far...
# Inserted 460500 records so far...
# Inserted 461000 records so far...
# Inserted 461500 records so far...
# Inserted 462000 records so far...
# Inserted 462500 records so far...
# Inserted 463000 records so far...
# Inserted 463500 records so far...
# Inserted 464000 records so far...
# Inserted 464500 records so far...
# Inserted 465000 records so far...
# Inserted 465500 records so far...
# Inserted 466000 records so far...
# Inserted 466500 records so far...
# Inserted 467000 records so far...
# Inserted 467500 records so far...
# Inserted 468000 records so far...
# Inserted 468500 records so far...
# Inserted 469000 records so far...
# Inserted 469500 records so far...
# Inserted 470000 records so far...
# Inserted 470500 records so far...
# Inserted 471000 records so far...
# Inserted 471500 records so far...
# Inserted 472000 records so far...
# Inserted 472500 records so far...
# Inserted 473000 records so far...
# Inserted 473500 records so far...
# Inserted 474000 records so far...
# Inserted 474500 records so far...
# Inserted 475000 records so far...
# Inserted 475500 records so far...
# Inserted 476000 records so far...
# Inserted 476500 records so far...
# Inserted 477000 records so far...
# Inserted 477500 records so far...
# Inserted 478000 records so far...
# Inserted 478500 records so far...
# Inserted 479000 records so far...
# Inserted 479500 records so far...
# Inserted 480000 records so far...
# Inserted 480500 records so far...
# Inserted 481000 records so far...
# Inserted 481500 records so far...
# Inserted 482000 records so far...
# Inserted 482500 records so far...
# Inserted 483000 records so far...
# Inserted 483500 records so far...
# Inserted 484000 records so far...
# Inserted 484500 records so far...
# Inserted 485000 records so far...
# Inserted 485500 records so far...
# Inserted 486000 records so far...
# Inserted 486500 records so far...
# Inserted 487000 records so far...
# Inserted 487500 records so far...
# Inserted 488000 records so far...
# Inserted 488500 records so far...
# Inserted 489000 records so far...
# Inserted 489500 records so far...
# Inserted 490000 records so far...
# Inserted 490500 records so far...
# Inserted 491000 records so far...
# Inserted 491500 records so far...
# Inserted 492000 records so far...
# Inserted 492500 records so far...
# Inserted 493000 records so far...
# Inserted 493500 records so far...
# Inserted 494000 records so far...
# Inserted 494500 records so far...
# Inserted 495000 records so far...
# Inserted 495500 records so far...
# Inserted 496000 records so far...
# Inserted 496500 records so far...
# Inserted 497000 records so far...
# Inserted 497500 records so far...
# Inserted 498000 records so far...
# Inserted 498500 records so far...
# Inserted 499000 records so far...
# Inserted 499500 records so far...
# Inserted 500000 records so far...
# Inserted 500500 records so far...
# Inserted 501000 records so far...
# Inserted 501500 records so far...
# Inserted 502000 records so far...
# Inserted 502500 records so far...
# Inserted 503000 records so far...
# Inserted 503500 records so far...
# Inserted 504000 records so far...
# Inserted 504500 records so far...
# Inserted 505000 records so far...
# Inserted 505500 records so far...
# Inserted 506000 records so far...
# Inserted 506500 records so far...
# Inserted 507000 records so far...
# Inserted 507500 records so far...
# Inserted 508000 records so far...
# Inserted 508500 records so far...
# Inserted 509000 records so far...
# Inserted 509500 records so far...
# Inserted 510000 records so far...
# Inserted 510500 records so far...
# Inserted 511000 records so far...
# Inserted 511500 records so far...
# Inserted 512000 records so far...
# Inserted 512500 records so far...
# Inserted 513000 records so far...
# Inserted 513500 records so far...
# Inserted 514000 records so far...
# Inserted 514500 records so far...
# Inserted 515000 records so far...
# Inserted 515500 records so far...
# Inserted 516000 records so far...
# Inserted 516500 records so far...
# Inserted 517000 records so far...
# Inserted 517500 records so far...
# Inserted 518000 records so far...
# Inserted 518500 records so far...
# Inserted 519000 records so far...
# Inserted 519500 records so far...
# Inserted 520000 records so far...
# Inserted 520500 records so far...
# Inserted 521000 records so far...
# Inserted 521500 records so far...
# Inserted 522000 records so far...
# Inserted 522500 records so far...
# Inserted 523000 records so far...
# Inserted 523500 records so far...
# Inserted 524000 records so far...
# Inserted 524500 records so far...
# Inserted 525000 records so far...
# Inserted 525500 records so far...
# Inserted 526000 records so far...
# Inserted 526500 records so far...
# Inserted 527000 records so far...
# Inserted 527500 records so far...
# Inserted 528000 records so far...
# Inserted 528500 records so far...
# Inserted 529000 records so far...
# Inserted 529500 records so far...
# Inserted 530000 records so far...
# Inserted 530500 records so far...
# Inserted 531000 records so far...
# Inserted 531500 records so far...
# Inserted 532000 records so far...
# Inserted 532500 records so far...
# Inserted 533000 records so far...
# Inserted 533500 records so far...
# Inserted 534000 records so far...
# Inserted 534500 records so far...
# Inserted 535000 records so far...
# Inserted 535500 records so far...
# Inserted 536000 records so far...
# Inserted 536500 records so far...
# Inserted 537000 records so far...
# Inserted 537500 records so far...
# Inserted 538000 records so far...
# Inserted 538500 records so far...
# Inserted 539000 records so far...
# Inserted 539500 records so far...
# Inserted 540000 records so far...
# Inserted 540500 records so far...
# Inserted 541000 records so far...
# Inserted 541500 records so far...
# Inserted 542000 records so far...
# Inserted 542500 records so far...
# Inserted 543000 records so far...
# Inserted 543500 records so far...
# Inserted 544000 records so far...
# Inserted 544500 records so far...
# Inserted 545000 records so far...
# Inserted 545500 records so far...
# Inserted 546000 records so far...
# Inserted 546500 records so far...
# Inserted 547000 records so far...
# Inserted 547500 records so far...
# Inserted 548000 records so far...
# Inserted 548500 records so far...
# Inserted 549000 records so far...
# Inserted 549500 records so far...
# Inserted 550000 records so far...
# Inserted 550500 records so far...
# Inserted 551000 records so far...
# Inserted 551500 records so far...
# Inserted 552000 records so far...
# Inserted 552500 records so far...
# Inserted 553000 records so far...
# Inserted 553500 records so far...
# Inserted 554000 records so far...
# Inserted 554500 records so far...
# Inserted 555000 records so far...
# Inserted 555500 records so far...
# Inserted 556000 records so far...

# %%
count
# Out:
# 7390
