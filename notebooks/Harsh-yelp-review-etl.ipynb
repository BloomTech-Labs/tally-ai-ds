# %%
import dask

# Make sure dask is latest version
assert dask.__version__ == "2.17.2"

# %% [markdown]
# ### Instructions to use in Sagemaker
#
# In order to use dask
#
# 1. Activate Conda Python 3 `source activate python3`
# 2. Install dask and s3fs `conda install dask s3fs -c conda-forge -y`

# %%
import boto3
import dask.dataframe as dd
from sagemaker import get_execution_role
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

role = get_execution_role()

pd.set_option('display.max_columns', None)

# %%
# Utility functions here

def create_s3_file_url(folder, file_name,bucket='tally-ai-dspt3'):
    return 's3://{}/{}/{}'.format(bucket, folder, file_name)

# %% [markdown]
# ## Loading Yelp `business` data

# %%
folder = 'yelp-kaggle-raw-data'
file_name = 'yelp_academic_dataset_business.json'
s3_business = create_s3_file_url(folder, file_name)
print(f"Fetching data from {s3_business}")
business = dd.read_json(s3_business, lines=True, blocksize=32e6)
business.head()
# Out:
# Fetching data from s3://tally-ai-dspt3/yelp-kaggle-raw-data/yelp_academic_dataset_business.json
#                      address  \
# 0            10913 Bailey Rd
# 1  8880 E Via Linda, Ste 107
# 2      3554 Rue Notre-Dame O
# 3             1015 Sharp Cir
# 4         4827 E Downing Cir
#
#                                           attributes             business_id  \
# 0  {'BusinessAcceptsCreditCards': 'True', 'BikePa...  f9NumwFMBDn751xgFiRbNA
# 1  {'GoodForKids': 'True', 'ByAppointmentOnly': '...  Yzvjg0SayhoZgCljUJRF9Q
# 2                                               None  XNoUzKckATkOD1hP6vghZg
# 3  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...  6OAZjbxqM5ol29BuHsil3w
# 4  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...  51M2Kk903DFYI6gnB5I6SQ
#
#                                           categories             city  \
# 0  Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...        Cornelius
# 1  Health & Medical, Fitness & Instruction, Yoga,...       Scottsdale
# 2                   Pets, Pet Services, Pet Groomers         Montreal
# 3  Hardware Stores, Home Services, Building Suppl...  North Las Vegas
# 4  Home Services, Plumbing, Electricians, Handyma...             Mesa
#
#                                                hours  is_open   latitude  \
# 0  {'Monday': '10:0-18:0', 'Tuesday': '11:0-20:0'...        1  35.462724
# 1                                               None        1  33.569404
# 2                                               None        1  45.479984
# 3  {'Monday': '7:0-16:0', 'Tuesday': '7:0-16:0', ...        0  36.219728
# 4  {'Monday': '0:0-0:0', 'Tuesday': '9:0-16:0', '...        1  33.428065
#
#     longitude                      name postal_code  review_count  stars state
# 0  -80.852612  The Range At Lake Norman       28031            36    3.5    NC
# 1 -111.890264         Carlos Santo, NMD       85258             4    5.0    AZ
# 2  -73.580070                   Felinus     H4C 1P4             5    5.0    QC
# 3 -115.127725      Nevada House of Hose       89030             3    2.5    NV
# 4 -111.726648   USE MY GUY SERVICES LLC       85205            26    4.5    AZ

# %% [markdown]
# ### Dropping Missing Values
#
# Before dropping na in `categories`

# %%
business.compute().shape
# Out:
# (209393, 14)

# %% [markdown]
# After dropping na in categories

# %%
business = business.dropna(subset=['categories'])
business.compute().shape
# Out:
# (208869, 14)

# %% [markdown]
# ### List of Unique Categories

# %%
business["categories"].unique().compute()
# Out:
# 0         Active Life, Gun/Rifle Ranges, Guns & Ammo, Sh...
# 102492    Department Stores, Food, Mobile Phones, Fashio...
# 102493    American (New), Food, Burgers, Restaurants, Fa...
# Name: categories, Length: 102494, dtype: object

# %% [markdown]
# ## Filtering `restaurants` only

# %% [markdown]
# Before filtering for `restaurants` businesses, total unique businesses are

# %%
business["categories"].unique().compute().shape
# Out:
# (102494,)

# %%
restaurants = business[business["categories"].str.contains("Restaurants")]
restaurants.head()
# Out:
#                              address  \
# 8                     404 E Green St
# 20          4508 E Independence Blvd
# 24  15480 Bayview Avenue, unit D0110
# 25                   300 John Street
# 30                13071 Yonge Street
#
#                                            attributes             business_id  \
# 8   {'RestaurantsAttire': 'u'casual'', 'Restaurant...  pQeaRpvuhoEqudo3uymHIQ
# 20  {'RestaurantsGoodForGroups': 'True', 'OutdoorS...  CsLQLiRoafpJPJSkNX2h5Q
# 24  {'RestaurantsTableService': 'False', 'Restaura...  eBEfgOPG7pvFhb2wcG9I7w
# 25  {'GoodForKids': 'True', 'RestaurantsTakeOut': ...  lu7vtrp_bE9PnxWfA8g4Pg
# 30  {'Ambience': '{'touristy': False, 'hipster': F...  9sRGfSVEfLhN_km60YruTA
#
#                                            categories           city  \
# 8   Ethnic Food, Food Trucks, Specialty Food, Impo...      Champaign
# 20         Food, Restaurants, Grocery, Middle Eastern      Charlotte
# 24             Restaurants, Cheesesteaks, Poutineries         Aurora
# 25       Japanese, Fast Food, Food Court, Restaurants      Thornhill
# 30  Persian/Iranian, Turkish, Middle Eastern, Rest...  Richmond Hill
#
#                                                 hours  is_open   latitude  \
# 8   {'Monday': '11:30-14:30', 'Tuesday': '11:30-14...        1  40.110446
# 20                                               None        0  35.194894
# 24  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  44.010962
# 25                                               None        1  43.820492
# 30  {'Tuesday': '12:0-21:0', 'Wednesday': '12:0-21...        1  43.947011
#
#     longitude                 name postal_code  review_count  stars state
# 8  -88.233073  The Empanadas House       61820             5    4.5    IL
# 20 -80.767442     Middle East Deli       28205             5    3.0    NC
# 24 -79.448677      Philthy Phillys     L4G 7J1             4    4.5    ON
# 25 -79.398466         Banzai Sushi     L3T 5W4             7    4.5    ON
# 30 -79.454862   Apadana Restaurant     L4E 1A5             3    3.0    ON

# %% [markdown]
# After filtering for `restaurants` total unique businesses dropped

# %%
restaurants.compute().shape
# Out:
# (63944, 14)

# %% [markdown]
# ### Rename `stars` to `business_stars`

# %%
restaurants['business_stars'] = restaurants['stars']
restaurants = restaurants.drop("stars", axis=1)
restaurants.head()
# Out:
#                              address  \
# 8                     404 E Green St
# 20          4508 E Independence Blvd
# 24  15480 Bayview Avenue, unit D0110
# 25                   300 John Street
# 30                13071 Yonge Street
#
#                                            attributes             business_id  \
# 8   {'RestaurantsAttire': 'u'casual'', 'Restaurant...  pQeaRpvuhoEqudo3uymHIQ
# 20  {'RestaurantsGoodForGroups': 'True', 'OutdoorS...  CsLQLiRoafpJPJSkNX2h5Q
# 24  {'RestaurantsTableService': 'False', 'Restaura...  eBEfgOPG7pvFhb2wcG9I7w
# 25  {'GoodForKids': 'True', 'RestaurantsTakeOut': ...  lu7vtrp_bE9PnxWfA8g4Pg
# 30  {'Ambience': '{'touristy': False, 'hipster': F...  9sRGfSVEfLhN_km60YruTA
#
#                                            categories           city  \
# 8   Ethnic Food, Food Trucks, Specialty Food, Impo...      Champaign
# 20         Food, Restaurants, Grocery, Middle Eastern      Charlotte
# 24             Restaurants, Cheesesteaks, Poutineries         Aurora
# 25       Japanese, Fast Food, Food Court, Restaurants      Thornhill
# 30  Persian/Iranian, Turkish, Middle Eastern, Rest...  Richmond Hill
#
#                                                 hours  is_open   latitude  \
# 8   {'Monday': '11:30-14:30', 'Tuesday': '11:30-14...        1  40.110446
# 20                                               None        0  35.194894
# 24  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  44.010962
# 25                                               None        1  43.820492
# 30  {'Tuesday': '12:0-21:0', 'Wednesday': '12:0-21...        1  43.947011
#
#     longitude                 name postal_code  review_count state  \
# 8  -88.233073  The Empanadas House       61820             5    IL
# 20 -80.767442     Middle East Deli       28205             5    NC
# 24 -79.448677      Philthy Phillys     L4G 7J1             4    ON
# 25 -79.398466         Banzai Sushi     L3T 5W4             7    ON
# 30 -79.454862   Apadana Restaurant     L4E 1A5             3    ON
#
#     business_stars
# 8              4.5
# 20             3.0
# 24             4.5
# 25             4.5
# 30             3.0

# %% [markdown]
# ## Exporting  `business` as CSV to S3

# %%
file_name = 'business.csv'
folder = 'yelp-restaurants'
s3_file_name = create_s3_file_url(folder, file_name)
print(f"Storing to {s3_file_name}")
restaurants.to_csv(s3_file_name, single_file = True)
# Out:
# Storing to s3://tally-ai-dspt3/yelp-restaurants/business.csv
# ['tally-ai-dspt3/yelp-restaurants/business.csv']

# %% [markdown]
# ## Loading Yelp `reviews` ~ 6GB data

# %%
folder = 'yelp-kaggle-raw-data'
file_name = 'yelp_academic_dataset_review.json'
s3_reviews = create_s3_file_url(folder, file_name)
print(f"Fetching data from {s3_reviews}")
reviews = dd.read_json(s3_reviews, blocksize=32e6)
reviews.head()
# Out:
# Fetching data from s3://tally-ai-dspt3/yelp-kaggle-raw-data/yelp_academic_dataset_review.json
#               business_id  cool                date  funny  \
# 0  -MhfebM0QIsKt87iDN-FNw     0 2015-04-15 05:21:16      0
# 1  lbrU8StCq3yDfr-QMnGrmQ     0 2013-12-07 03:16:52      1
# 2  HQl28KMwrEKHqhFrrDqVNQ     0 2015-12-05 03:18:11      0
# 3  5JxlZaqCnk1MnbgRirs40Q     0 2011-05-27 05:30:52      0
# 4  IS4cv902ykd8wj1TR0N3-A     0 2017-01-14 21:56:57      0
#
#                 review_id  stars  \
# 0  xQY8N_XvtGbearJ5X4QryQ      2
# 1  UmFMZ8PyXZTY2QcwzsfQYA      1
# 2  LG2ZaYiOgpr2DK_90pYjNw      5
# 3  i6g_oA9Yf9Y31qt0wibXpw      1
# 4  6TdNDKywdbjoTkizeMce8A      4
#
#                                                 text  useful  \
# 0  As someone who has worked with many museums, I...       5
# 1  I am actually horrified this place is still in...       1
# 2  I love Deagan's. I do. I really do. The atmosp...       1
# 3  Dismal, lukewarm, defrosted-tasting "TexMex" g...       0
# 4  Oh happy day, finally have a Canes near my cas...       0
#
#                   user_id
# 0  OwjRMXRC0KyPrIlcjaXeFQ
# 1  nIJD_7ZXHq-FX8byPMOkMQ
# 2  V34qejxNsCbcgD8C0HVk-Q
# 3  ofKDkJKXSKZXu5xJNGiiBQ
# 4  UgMW8bLE0QMJDCkQ1Ax5Mg

# %% [markdown]
# #### Total Reviews before merging

# %%
reviews.compute().shape
# Out:
# (8021122, 9)

# %% [markdown]
# ## Merging `business` and `reviews` data

# %%
restaurants_reviews = restaurants.merge(reviews, on="business_id",  how = 'inner')
restaurants_reviews.head()
# Out:
#           address                                         attributes  \
# 0  15 N Butler St  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 1  15 N Butler St  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 2  15 N Butler St  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 3  15 N Butler St  {'BusinessAcceptsCreditCards': 'True', 'Busine...
# 4  15 N Butler St  {'BusinessAcceptsCreditCards': 'True', 'Busine...
#
#               business_id                                   categories  \
# 0  5p5YW_5bMOSuLIQjkJPO3w  Restaurants, Pizza, Italian, American (New)
# 1  5p5YW_5bMOSuLIQjkJPO3w  Restaurants, Pizza, Italian, American (New)
# 2  5p5YW_5bMOSuLIQjkJPO3w  Restaurants, Pizza, Italian, American (New)
# 3  5p5YW_5bMOSuLIQjkJPO3w  Restaurants, Pizza, Italian, American (New)
# 4  5p5YW_5bMOSuLIQjkJPO3w  Restaurants, Pizza, Italian, American (New)
#
#       city                                              hours  is_open  \
# 0  Madison  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...        1
# 1  Madison  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...        1
# 2  Madison  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...        1
# 3  Madison  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...        1
# 4  Madison  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...        1
#
#     latitude  longitude       name postal_code  review_count  stars_x state  \
# 0  43.077208 -89.381527  Naples 15       53703           247      4.0    WI
# 1  43.077208 -89.381527  Naples 15       53703           247      4.0    WI
# 2  43.077208 -89.381527  Naples 15       53703           247      4.0    WI
# 3  43.077208 -89.381527  Naples 15       53703           247      4.0    WI
# 4  43.077208 -89.381527  Naples 15       53703           247      4.0    WI
#
#    cool                date  funny               review_id  stars_y  \
# 0     3 2015-09-24 01:48:06      0  ueAiZ8f-jH7gKKuG0Bv3Gw        5
# 1     2 2016-02-12 15:07:33      0  7zxEvUQwjXLl3vGl3aYhjQ        5
# 2     1 2015-05-13 05:20:33      0  ljP15ya0teoDyZz1Ms1rqQ        4
# 3     0 2018-05-29 02:52:02      0  h2bXl2byo--CaBuf8QMUfA        5
# 4     0 2018-06-09 11:07:48      0  rxO7gNmdpjamcoHPCfdmZg        1
#
#                                                 text  useful  \
# 0  The most fantastic Italian food in Madison---d...       3
# 1  Naples 15 is wonderful and Chef Salvatore is a...       1
# 2  My friends and I decided to check out Naples 1...       1
# 3  I went to Naples 15 on the Friday of Memorial ...       1
# 4  Food is pricey, quantity moderate and quality ...       1
#
#                   user_id
# 0  tdS2jvf9LPfE4XS5Kka9sw
# 1  DBtHPn6TOBpXq6BAuFdcow
# 2  8EipJXehR14DD9x9N7RSSw
# 3  6GC4KK_FW1pMGXt7qDUQGg
# 4  lX-V2SVG2rWtkeW6LRuCpg

# %% [markdown]
# 12617  This was by far the best Italian restaurant I'...       0
# 13423  My entire experience at Naples 15 was phenomen...       0
# 15661  Naples 15 is through-and-through the best Ital...       1
# 17590  I have eaten in in Rome, Florence, Napoli, Ver...       1
# 20193  I have been to Naples 15 7 or 8 times and had ...       1
#
#                       user_id
# 6122   tdS2jvf9LPfE4XS5Kka9sw
# 20739  DBtHPn6TOBpXq6BAuFdcow
# 25501  8EipJXehR14DD9x9N7RSSw
# 26200  6GC4KK_FW1pMGXt7qDUQGg
# 27315  lX-V2SVG2rWtkeW6LRuCpg
# 31778  aZdsBvIJR03Vm99mKYBiew
# 37089  4oH2DWaYEn8bBFW9w8bScQ
# 6271   rEdLHGNhCfJXSFq4SQXhkQ
# 13663  LMUn-OsM_AdIipX2CflLgQ
# 14634  ffA7RP_FY9rKpTi4DRdWeA
# 17257  TRy4Ychd6IXs24WH_TkN-Q
# 17578  e9bVxMuG-1NIJWqT_pDEmQ
# 24078  23rmcrD81AmQx1PPvA8wgw
# 28100  b5kepLk7zzHy4zaWD-DVsg
# 28290  7AAukiE74uGYGEevr9mNUA
# 31941  zwBpOOb2GF3B4Iw3zH3efw
# 32087  ztLkgaRJIq_AKHKWZO86eg
# 37125  0sMDR5ct4SIIZZpcmiVvgg
# 316    dsY_UbXxpRV770x2fmTVKA
# 645    4FT78_qxh7Z8kkY1lAZCqg
# 1884   2UyRZRxQKof_Vhriphj46g
# 2469   24f2R1VuQTcR72FqbqC6IA
# 4150   cmmYFJa0bD2FZmlpLGBBog
# 4519   nXsXUIiNN2GLfuyB8B98kQ
# 13980  YUl6pXwA2hiHPX13KgJ0tw
# 14887  BhXCPy-PK90Qqce3iEqpJA
# 16572  xgYjHrgfof3t4ZFGPISQyA
# 23687  kT-giTkabN1I_KVIsTtGFw
# 27336  pi5ytbgdypYGB1jvT1qzUg
# 31993  S2nuddBBycBSwV_zdlsGyw
# ...                       ...
# 24244  c-7c4DlD7yRnwjqNe3m6Vg
# 26009  QVwRbinWU9RPqvy_ptt3FA
# 27060  B2JurUiLrCO8lj-y7lu8tQ
# 186    1ibWK2iAVktUPNzIFiimpg
# 198    d5WLqmTMvmL7-RmUDVKqqQ
# 5079   JzWfTtBAyAfe7Mx86UwA-g
# 8125   tyDL3sF9I3CgbTRURuYg7A
# 8400   kpbBeYjAsBmSyTMLOP3Iyw
# 22945  -PTtMZYVawqKC6-vIds9lQ
# 28931  -9gZqyvOZWxqvvbuyDxTsg
# 31355  AdwqaeOh8RLaAAhT7jLpRg
# 3900   rGdVUSwf8tIRLmqlSLwXsQ
# 4793   0Qyjoapw_9RAp5FNahgMKw
# 5613   E99Mnqrqdx5FZ_17OiBBDg
# 5678   Peg0fOLkdGdmPkPxuXEPlw
# 8935   LpqGmdkWx4c90r0Ly3cSIQ
# 13976  tYWZenAKSPcSY2xwzi_z7Q
# 17320  HtaSDsm0rI9qYKqI-_m-mQ
# 21055  4Z4n1gmQelTsqDu__NYEfg
# 21286  70HubR9J_Ohz6d6NTX3fHw
# 26838  XuFJHNgD2tGiIdcHTWZ-Lg
# 29548  4qr5zkIt1uLEYVLOVExwNQ
# 34421  0xcrfTczuBNdm1em7RaQOA
# 3922   P_fDCO-52XJ2HLLmuiQMbg
# 11939  D3ubzB6RdOiMwJ6JFIL2Zw
# 12617  xQ2Isj_j1a1Vvn_QARargg
# 13423  5xiPeYGL938nKddZOY6KlA
# 15661  Wt3h0iR1MJLBr5m3mCOdbA
# 17590  f_0T3VC6Q4_kNsf1Iv9byg
# 20193  kghQfvmWmqjS3CQ1KfdSyg
#
# [255 rows x 9 columns]

# %%
restaurants_reviews[(restaurants_reviews["business_id"] == "5p5YW_5bMOSuLIQjkJPO3w") & (restaurants_reviews["review_id"] == "ueAiZ8f-jH7gKKuG0Bv3Gw")].compute()
# Out:
#           address                                         attributes  \
# 0  15 N Butler St  {'BusinessAcceptsCreditCards': 'True', 'Busine...
#
#               business_id                                   categories  \
# 0  5p5YW_5bMOSuLIQjkJPO3w  Restaurants, Pizza, Italian, American (New)
#
#       city                                              hours  is_open  \
# 0  Madison  {'Monday': '17:0-22:0', 'Tuesday': '17:0-22:0'...        1
#
#     latitude  longitude       name postal_code  review_count  stars_x state  \
# 0  43.077208 -89.381527  Naples 15       53703           247      4.0    WI
#
#    cool                date  funny               review_id  stars_y  \
# 0     3 2015-09-24 01:48:06      0  ueAiZ8f-jH7gKKuG0Bv3Gw        5
#
#                                                 text  useful  \
# 0  The most fantastic Italian food in Madison---d...       3
#
#                   user_id
# 0  tdS2jvf9LPfE4XS5Kka9sw

# %%
restaurants_reviews = restaurants_reviews.rename(columns={'stars_y': 'review_stars'})

# %%
cols_to_keep = ["review_id", "business_id", "review_stars", "date", "text"]
restaurants_reviews = restaurants_reviews[cols_to_keep]
restaurants_reviews.head()
# Out:
#                 review_id             business_id  review_stars  \
# 0  41CAcEh3lnhCL-Azg1cbRw  5p5YW_5bMOSuLIQjkJPO3w             5
# 1  w-tAhWGOV3jFG6FHiz9qPg  5p5YW_5bMOSuLIQjkJPO3w             5
# 2  Rsuzk8b1Jp6d6FAsh9iuYw  5p5YW_5bMOSuLIQjkJPO3w             2
# 3  fvhaYWPyjRBK64xh62cpMg  5p5YW_5bMOSuLIQjkJPO3w             1
# 4  dtMfGwj0qcWIwkMORFuiIw  5p5YW_5bMOSuLIQjkJPO3w             5
#
#                  date                                               text
# 0 2013-10-26 01:42:06  I had noticed a sign for Naples15 one time whe...
# 1 2015-07-17 14:50:55  One of the top 5 meals in my life.  The atmosp...
# 2 2017-10-26 00:50:17  We had  a Groupon for this restaurant and we w...
# 3 2014-06-13 00:42:39  Are you kidding me?  Their prices are outrageo...
# 4 2016-05-07 20:38:55  This place is awesome. Salvatore Di Scala, own...

# %% [markdown]
# ## Exporting `reviews` as CSV to S3

# %%
file_name = 'reviews.csv'
folder = 'yelp-restaurants'
s3_file_name = create_s3_file_url(folder, file_name)
print(f"Storing to {s3_file_name}")
restaurants_reviews.to_csv(s3_file_name, single_file = True)
# Out:
# Storing to s3://tally-ai-dspt3/yelp-restaurants/reviews.csv
