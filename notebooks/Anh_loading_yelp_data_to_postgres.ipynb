# %%
import os
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# Load pandas dataframe
def load_data(url):
    if url.endswith(".csv") or "csv" in url:
        df = pd.read_csv(url)
    else:
        df = None
    return df

# %% [markdown]
# ## Load `business` to Postgres

# %%
biz_url = 'https://tally-ai-dspt3.s3.amazonaws.com/yelp-restaurants/business_with_cuisine.csv'

business = load_data(biz_url)
business = business.drop(columns=["Unnamed: 0"])
business.head()
# Out:
#    Unnamed: 0.1               address  \
# 0             0  2706 E University Dr
# 1           139    1017 E Apache Blvd
# 2           258  4005 N Scottsdale Rd
# 3           993               S Tryon
# 4          1174       20825 N Pima Rd
#
#                                           attributes             business_id  \
# 0  {'Caters': 'False', 'OutdoorSeating': 'False',...  j9bWpCRwpDVfwVT_V85qeA
# 1  {'NoiseLevel': "u'average'", 'BusinessAcceptsC...  W7hCuNdn2gzehta6eSHzgQ
# 2  {'RestaurantsAttire': "'casual'", 'Alcohol': "...  8nP8ghEpT6WFcM6tfqAaGA
# 3  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...  3C0bnFhjkgYP9mWORKg6cA
# 4  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...  VBVqHnViRLSYAqP7v8iNNQ
#
#                                           categories        city  \
# 0  Food, Ethnic Food, Specialty Food, Restaurants...        Mesa
# 1                 Restaurants, Fish & Chips, Seafood       Tempe
# 2  Ice Cream & Frozen Yogurt, Sandwiches, Food, A...  Scottsdale
# 3        Hot Dogs, Food, Street Vendors, Restaurants   Charlotte
# 4        Mexican, Restaurants, Food, Salad, Desserts  Scottsdale
#
#                                                hours  is_open   latitude  \
# 0  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...        1  33.423705
# 1  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...        1  33.414507
# 2  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  33.493775
# 3  {'Tuesday': '11:0-14:30', 'Wednesday': '11:0-1...        1  35.226911
# 4  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...        1  33.674880
#
#     longitude                 name  postal_code  review_count state  \
# 0 -111.772890          Papaya Thai        85213           130    AZ
# 1 -111.923721  Pete's Fish & Chips        85281           117    AZ
# 2 -111.925933           Sugar Bowl        85251           720    AZ
# 3  -80.843823            Chili Man        28202           172    NC
# 4 -111.888635     Jalapeño Inferno        85255           247    AZ
#
#    business_stars   cuisine
# 0             2.5      thai
# 1             2.0     other
# 2             3.5  american
# 3             5.0     other
# 4             3.5   mexican

# %%
business = business.drop('categories', axis=1)
business.head()
# Out:
#    Unnamed: 0.1               address  \
# 0             0  2706 E University Dr
# 1           139    1017 E Apache Blvd
# 2           258  4005 N Scottsdale Rd
# 3           993               S Tryon
# 4          1174       20825 N Pima Rd
#
#                                           attributes             business_id  \
# 0  {'Caters': 'False', 'OutdoorSeating': 'False',...  j9bWpCRwpDVfwVT_V85qeA
# 1  {'NoiseLevel': "u'average'", 'BusinessAcceptsC...  W7hCuNdn2gzehta6eSHzgQ
# 2  {'RestaurantsAttire': "'casual'", 'Alcohol': "...  8nP8ghEpT6WFcM6tfqAaGA
# 3  {'RestaurantsTakeOut': 'True', 'RestaurantsDel...  3C0bnFhjkgYP9mWORKg6cA
# 4  {'RestaurantsTakeOut': 'True', 'GoodForKids': ...  VBVqHnViRLSYAqP7v8iNNQ
#
#          city                                              hours  is_open  \
# 0        Mesa  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...        1
# 1       Tempe  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...        1
# 2  Scottsdale  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1
# 3   Charlotte  {'Tuesday': '11:0-14:30', 'Wednesday': '11:0-1...        1
# 4  Scottsdale  {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...        1
#
#     latitude   longitude                 name  postal_code  review_count  \
# 0  33.423705 -111.772890          Papaya Thai        85213           130
# 1  33.414507 -111.923721  Pete's Fish & Chips        85281           117
# 2  33.493775 -111.925933           Sugar Bowl        85251           720
# 3  35.226911  -80.843823            Chili Man        28202           172
# 4  33.674880 -111.888635     Jalapeño Inferno        85255           247
#
#   state  business_stars   cuisine
# 0    AZ             2.5      thai
# 1    AZ             2.0     other
# 2    AZ             3.5  american
# 3    NC             5.0     other
# 4    AZ             3.5   mexican

# %%
print(f"Total records in business: {business.shape}")
# Out:
# Total records in business: (7390, 15)

# %%
# Take sample from the dask dataframe
sample_biz_df = business.sample(frac=1, replace=False, random_state=42)
sample_biz_df
# Out:
#       Unnamed: 0.1                           address  \
# 7266       3178472         7318 E Shea Blvd, Ste 101
# 3653       1480737                   132 W Church St
# 1539        570412                    1051 W 10th St
# 6071       2595326                  4510 Paradise Rd
# 4165       1698300   3500 Las Vegas Blvd S, Ste R06A
# ...            ...                               ...
# 5191       2160597  4325 E Indian School Rd, Ste 150
# 5226       2180800               3921 E Guadalupe Rd
# 5390       2255517              6430 S McClintock Dr
# 860         302507    6587 Las Vegas Blvd S, Ste 171
# 7270       3179643      6455 S Rainbow Blvd, Ste 101
#
#                                              attributes  \
# 7266  {'HasTV': 'True', 'Alcohol': "u'full_bar'", 'R...
# 3653  {'BYOBCorkage': 'None', 'RestaurantsGoodForGro...
# 1539  {'GoodForKids': 'False', 'RestaurantsAttire': ...
# 6071  {'Caters': 'False', 'BusinessAcceptsCreditCard...
# 4165  {'Smoking': "u'no'", 'RestaurantsGoodForGroups...
# ...                                                 ...
# 5191  {'RestaurantsTakeOut': 'True', 'BikeParking': ...
# 5226  {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 5390  {'Ambience': "{'romantic': False, 'intimate': ...
# 860   {'BusinessParking': "{'garage': False, 'street...
# 7270  {'RestaurantsReservations': 'True', 'WiFi': "u...
#
#                  business_id             city  \
# 7266  8YL_Cm7lYGLfPvp5sseyrQ       Scottsdale
# 3653  0-WocGTpO3Zm4q1Zzz49Rw        Champaign
# 1539  ZLPAP1YKL56ODigLn4wd3w        Cleveland
# 6071  cJWbbvGmyhFiBpG_5hf5LA        Las Vegas
# 4165  uf1Bw8r7f0TFh5drTk_98w        Las Vegas
# ...                      ...              ...
# 5191  Y_9f9tzVRaXjfT9Fa5_W9A          Phoenix
# 5226  TLbx_MR2dyFztoyR5d9H2A          Gilbert
# 5390  ELUUibdDcrZHyvE-e-QsVw            Tempe
# 860   n7V4cD-KqqE3OXk0irJTyA        Las Vegas
# 7270  k-tg18rWRibZ4jKpoqhb0Q  South Las Vegas
#
#                                                   hours  is_open   latitude  \
# 7266  {'Monday': '0:0-0:0', 'Tuesday': '15:0-21:0', ...        0  33.582229
# 3653  {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-2...        1  40.118531
# 1539  {'Monday': '11:30-21:30', 'Tuesday': '11:30-21...        0  41.501009
# 6071  {'Monday': '11:0-16:0', 'Tuesday': '11:0-23:0'...        1  36.107757
# 4165  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...        1  36.118723
# ...                                                 ...      ...        ...
# 5191  {'Monday': '10:45-18:0', 'Tuesday': '10:45-20:...        1  33.494173
# 5226  {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:30',...        1  33.364477
# 5390  {'Monday': '8:30-21:0', 'Tuesday': '11:0-21:0'...        0  33.362505
# 860   {'Monday': '10:0-0:0', 'Tuesday': '10:0-0:0', ...        1  36.068236
# 7270  {'Monday': '0:0-0:0', 'Tuesday': '11:30-21:30'...        1  36.071733
#
#        longitude                             name  postal_code  review_count  \
# 7266 -111.923257                   The Grand Blue        85260           131
# 3653  -88.244818                       Sushi Kame        61820           149
# 1539  -81.704360                  The Willeyville        44113           104
# 6071 -115.151691            Hofbräuhaus Las Vegas        89169          1762
# 4165 -115.173435             Smoked Burgers & BBQ        89109           197
# ...          ...                              ...          ...           ...
# 5191 -111.988030                         Uberrito        85018           175
# 5226 -111.706456  Salerno's Restaurant & Pizzeria        85234           230
# 5390 -111.912747              Mac's Broiler & Tap        85283           222
# 860  -115.178633                        GameWorks        89119           556
# 7270 -115.242963           Bonchon - SW Las Vegas        89118           435
#
#      state  business_stars   cuisine
# 7266    AZ             4.0     sushi
# 3653    IL             3.5     sushi
# 1539    OH             4.0  american
# 6071    NV             4.0     other
# 4165    NV             4.5     other
# ...    ...             ...       ...
# 5191    AZ             3.5   mexican
# 5226    AZ             4.0     pizza
# 5390    AZ             3.5  american
# 860     NV             3.5       pub
# 7270    NV             3.5    korean
#
# [7390 rows x 15 columns]

# %% [markdown]
# ## Load `reviews` to Postgres

# %%
rev_url = 'https://tally-ai-dspt3.s3.amazonaws.com/yelp-restaurants/reviews-6-15-20.csv'
rev = load_data(rev_url)
rev.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#   Unnamed: 0               review_id             business_id  reviews_stars  \
# 0          0  Oa-sapLub0wRAzxRKVmtDQ  j9bWpCRwpDVfwVT_V85qeA            5.0
# 1          1  NawvdCkVIvhMO_eMVMdBhw  j9bWpCRwpDVfwVT_V85qeA            3.0
# 2          2  uBWpaM4_PQ1NMB3N9nYkJA  j9bWpCRwpDVfwVT_V85qeA            1.0
# 3          3  EIcE_Xw9G5bDAY-XQ0Vosg  j9bWpCRwpDVfwVT_V85qeA            1.0
# 4          4  BXTxF_ijBmm5RPYELr-5RQ  j9bWpCRwpDVfwVT_V85qeA            4.0
#
#                   date                                               text
# 0  2017-02-23 03:10:38  Best thai food in Mesa, and you get so much fo...
# 1  2010-12-04 00:38:28  There are several contributing factors to the ...
# 2  2012-03-07 21:51:40  Moving to the Phoenix area was a shock to begi...
# 3  2011-10-06 00:29:51  Usually ok but today we went and ordered garde...
# 4  2013-11-20 03:08:02  I have never dined in. The restaurant itself i...

# %%
print(f"Total records in reviews: {rev.shape}")
# Out:
# Total records in reviews: (3244807, 6)

# %%
# Take sample from the dask dataframe
sample_rev_df = rev.sample(frac=.1, replace=False, random_state=42)
sample_rev_df
# Out:
#         Unnamed: 0               review_id             business_id  \
# 1022930    1022929  NTpWt7ZBsztNDaXDaFucRQ  4j0WfdS_lHG9uSH7cd1PFg
# 1958278    1958277  ESy8I_9j84fzPFqKJOs4vg  ABJjxuO6oh5D9R48-eAUdQ
# 2175959    2175958  ebwD3j69KHnrf_9VUUfZPg  L7txS44bvz862djgTOim9w
# 2865950    2865949  pDeQbN2eUkhsk9Lpd9hAuw  dThrFTK_bqo1woPvUgY70g
# 2228976    2228975  staVQafNxH_ZARsA7HKfrQ  iCQpiavjjPzJ5_3gPD5Ebg
# ...            ...                     ...                     ...
# 2881535    2881534  ZU03Yp4no5RyIIpqlu-1VQ  K7fip0nDFFdCC7OCnNOotQ
# 567780      567779  hyCijMm5vIjqmA4ic27ANw  frwKRRIIR0QMv25IKVDIMA
# 2863659    2863658  B8T4jfPt3dSi8zzD4DK34w  -bMZCfTK7fxFaURynKpBMA
# 3229469    3229468  r105P8nDMptOb_rqTX7k_Q  LtXy1VinKWfuLFslVarKRw
# 3017671    3017670  jZ6g9DVcanx6PHQi35_Ygw  7d7pZlKji6NozhHP1SrVqw
#
#          reviews_stars                 date  \
# 1022930            4.0  2019-06-24 03:09:01
# 1958278            5.0  2017-08-07 05:26:21
# 2175959            3.0  2016-05-22 04:17:07
# 2865950            5.0  2016-12-16 02:12:15
# 2228976            5.0  2012-03-16 07:59:07
# ...                ...                  ...
# 2881535            4.0  2013-10-23 15:02:51
# 567780             4.0  2014-12-18 18:48:52
# 2863659            1.0  2019-03-19 03:32:30
# 3229469            5.0  2019-01-20 10:16:18
# 3017671            4.0  2016-06-16 04:00:13
#
#                                                       text
# 1022930  Ordered via Postmates; this was our first time...
# 1958278  I went to the buffet in the afternoon on Satur...
# 2175959  I was fairly hungry so I opted for a few items...
# 2865950  We loved Pomelo!  The burger, the pizza and ri...
# 2228976  By far one of the best tasting pizzas ever!! I...
# ...                                                    ...
# 2881535  I went to Hyde as part of a huge bachelorette ...
# 567780   Delicious! I've only been there a couple of ti...
# 2863659  Will never return to this restaurant again! I'...
# 3229469  I love Fat burger. it's a must every time I vi...
# 3017671  If you want feel good food that you don't feel...
#
# [324481 rows x 6 columns]

# %% [markdown]
# # Setup SQL Alchemy, Create Tables and DB Models

# %%
from sqlalchemy.orm import relationship
from sqlalchemy import (
    Column,
    Integer,
    String,
    ForeignKey,
    DateTime,
    Float,
    Text,
    Boolean,
    UniqueConstraint,
    ForeignKeyConstraint,
)
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
import sqlalchemy as db

URI = 'postgres://tallyadmin:Tally_123456@tally-ai.cmfe7iubg1ts.us-east-1.rds.amazonaws.com:5432/tally'

Base = declarative_base()

### Helper Functions ##

def to_dict(inst, cls):
    """
    Convert the sql alchemy query result to a clean python dictionary.
    """
    convert = dict()
    # add your coversions for things like datetime's
    # and what-not that aren't serializable.
    d = dict()
    for c in cls.__table__.columns:
        v = getattr(inst, c.name)
        if c.type in convert.keys() and v is not None:
            try:
                d[c.name] = convert[c.type](v)
            except:
                d[c.name] = "Error:  Failed to covert using ", str(
                    convert[c.type])
        elif v is None:
            d[c.name] = str()
        else:
            d[c.name] = v
    return d

###########################
### Business Data Model ###
###########################


class Business(Base):
    __tablename__ = 'business'
    _class_name = 'Business'

    business_id	 = Column("business_id", String, primary_key=True)
    name = Column("name", String)
    address	= Column("address", String)
    city = Column("city", String)
    zipcode = Column("zipcode", String)
    latitude = Column("latitude", Float)
    longitude = Column("longitude", Float)
    attributes = Column("attributes", String)
    cuisine= Column("cuisine", String)
    review_count = Column("review_count", Integer)
    business_stars = Column("business_stars", Float)
    
    @property
    def json(self):
        return to_dict(self, self.__class__)


###########################
### Reviews Data Model ###
###########################


class Reviews(Base):
    __tablename__ = 'reviews'
    _class_name = 'Reviews'

    review_id = Column("review_id", String, primary_key=True)
    business_id	 = Column("business_id", String)
    reviews_stars = Column("reviews_stars", Float)
    datetime = Column("datetime", String)
    text = Column("text", Text)
    
    @property
    def json(self):
        return to_dict(self, self.__class__)

# DS Schema
dbschema = "tallyds"
engine = db.create_engine(URI,connect_args={'options': '-csearch_path={}'.format(dbschema)})

# Drop tables before creating new ones
Base.metadata.drop_all(bind=engine)

# Create new tables
Base.metadata.create_all(bind=engine)

# Create Session and attach db connection to it
Session = sessionmaker(bind=engine)

# %%
# Loop through each row of dask dataframe and insert into business table
session = Session()
count = 0
for row in business.itertuples():
    biz = Business()
    biz.business_id = row.business_id
    biz.name = row.name
    biz.address = row.address
    biz.city = row.city
    biz.zipcode = row.postal_code
    biz.latitude = row.latitude
    biz.longitude = row.longitude
    biz.attributes = row.attributes
    biz.cuisine = row.cuisine
    biz.review_count = row.review_count
    biz.business_stars = row.business_stars
    session.add(biz)
    count += 1
    if count % 500 == 0:
        print(f"Inserted {count} records so far...")
        session.commit()
session.commit()
session.close()
# Out:
# Inserted 500 records so far...
# Inserted 1000 records so far...
# Inserted 1500 records so far...
# Inserted 2000 records so far...
# Inserted 2500 records so far...
# Inserted 3000 records so far...
# Inserted 3500 records so far...
# Inserted 4000 records so far...
# Inserted 4500 records so far...
# Inserted 5000 records so far...
# Inserted 5500 records so far...
# Inserted 6000 records so far...
# Inserted 6500 records so far...
# Inserted 7000 records so far...

# %%
# Loop through each row of dask dataframe and insert into review table
session = Session()
count = 0
for row in rev.itertuples():
    rev = Reviews()
    rev.review_id = row.review_id
    rev.business_id = row.business_id
    rev.reviews_stars = row.reviews_stars
    rev.datetime = row.date
    rev.text = row.text
    session.add(rev)
    count += 1
    if count % 500 == 0:
        print(f"Inserted {count} records so far...")
        session.commit()
session.commit()
session.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# Inserted 745500 records so far...
# Inserted 746000 records so far...
# Inserted 746500 records so far...
# Inserted 747000 records so far...
# Inserted 747500 records so far...
# Inserted 748000 records so far...
# Inserted 748500 records so far...
# Inserted 749000 records so far...
# Inserted 749500 records so far...
# Inserted 750000 records so far...
# Inserted 750500 records so far...
# Inserted 751000 records so far...
# Inserted 751500 records so far...
# Inserted 752000 records so far...
# Inserted 752500 records so far...
# Inserted 753000 records so far...
# Inserted 753500 records so far...
# Inserted 754000 records so far...
# Inserted 754500 records so far...
# Inserted 755000 records so far...
# Inserted 755500 records so far...
# Inserted 756000 records so far...
# Inserted 756500 records so far...
# Inserted 757000 records so far...
# Inserted 757500 records so far...
# Inserted 758000 records so far...
# Inserted 758500 records so far...
# Inserted 759000 records so far...
# Inserted 759500 records so far...
# Inserted 760000 records so far...
# Inserted 760500 records so far...
# Inserted 761000 records so far...
# Inserted 761500 records so far...
# Inserted 762000 records so far...
# Inserted 762500 records so far...
# Inserted 763000 records so far...
# Inserted 763500 records so far...
# Inserted 764000 records so far...
# Inserted 764500 records so far...
# Inserted 765000 records so far...
# Inserted 765500 records so far...
# Inserted 766000 records so far...
# Inserted 766500 records so far...
# Inserted 767000 records so far...
# Inserted 767500 records so far...
# Inserted 768000 records so far...
# Inserted 768500 records so far...
# Inserted 769000 records so far...
# Inserted 769500 records so far...
# Inserted 770000 records so far...
# Inserted 770500 records so far...
# Inserted 771000 records so far...
# Inserted 771500 records so far...
# Inserted 772000 records so far...
# Inserted 772500 records so far...
# Inserted 773000 records so far...
# Inserted 773500 records so far...
# Inserted 774000 records so far...
# Inserted 774500 records so far...
# Inserted 775000 records so far...
# Inserted 775500 records so far...
# Inserted 776000 records so far...
# Inserted 776500 records so far...
# Inserted 777000 records so far...
# Inserted 777500 records so far...
# Inserted 778000 records so far...
# Inserted 778500 records so far...
# Inserted 779000 records so far...
# Inserted 779500 records so far...
# Inserted 780000 records so far...
# Inserted 780500 records so far...
# Inserted 781000 records so far...
# Inserted 781500 records so far...
# Inserted 782000 records so far...
# Inserted 782500 records so far...
# Inserted 783000 records so far...
# Inserted 783500 records so far...
# Inserted 784000 records so far...
# Inserted 784500 records so far...
# Inserted 785000 records so far...
# Inserted 785500 records so far...
# Inserted 786000 records so far...
# Inserted 786500 records so far...
# Inserted 787000 records so far...
# Inserted 787500 records so far...
# Inserted 788000 records so far...
# Inserted 788500 records so far...
# Inserted 789000 records so far...
# Inserted 789500 records so far...
# Inserted 790000 records so far...
# Inserted 790500 records so far...
# Inserted 791000 records so far...
# Inserted 791500 records so far...
# Inserted 792000 records so far...
# Inserted 792500 records so far...
# Inserted 793000 records so far...
# Inserted 793500 records so far...
# Inserted 794000 records so far...
# Inserted 794500 records so far...
# Inserted 795000 records so far...
# Inserted 795500 records so far...
# Inserted 796000 records so far...
# Inserted 796500 records so far...
# Inserted 797000 records so far...
# Inserted 797500 records so far...
# Inserted 798000 records so far...
# Inserted 798500 records so far...
# Inserted 799000 records so far...
# Inserted 799500 records so far...
# Inserted 800000 records so far...
# Inserted 800500 records so far...
# Inserted 801000 records so far...
# Inserted 801500 records so far...
# Inserted 802000 records so far...
# Inserted 802500 records so far...
# Inserted 803000 records so far...
# Inserted 803500 records so far...
# Inserted 804000 records so far...
# Inserted 804500 records so far...
# Inserted 805000 records so far...
# Inserted 805500 records so far...
# Inserted 806000 records so far...
# Inserted 806500 records so far...
# Inserted 807000 records so far...
# Inserted 807500 records so far...
# Inserted 808000 records so far...
# Inserted 808500 records so far...
# Inserted 809000 records so far...
# Inserted 809500 records so far...
# Inserted 810000 records so far...
# Inserted 810500 records so far...
# Inserted 811000 records so far...
# Inserted 811500 records so far...
# Inserted 812000 records so far...
# Inserted 812500 records so far...
# Inserted 813000 records so far...
# Inserted 813500 records so far...
# Inserted 814000 records so far...
# Inserted 814500 records so far...
# Inserted 815000 records so far...
# Inserted 815500 records so far...
# Inserted 816000 records so far...
# Inserted 816500 records so far...
# Inserted 817000 records so far...
# Inserted 817500 records so far...
# Inserted 818000 records so far...
# Inserted 818500 records so far...
# Inserted 819000 records so far...
# Inserted 819500 records so far...
# Inserted 820000 records so far...
# Inserted 820500 records so far...
# Inserted 821000 records so far...
# Inserted 821500 records so far...
# Inserted 822000 records so far...
# Inserted 822500 records so far...
# Inserted 823000 records so far...
# Inserted 823500 records so far...
# Inserted 824000 records so far...
# Inserted 824500 records so far...
# Inserted 825000 records so far...
# Inserted 825500 records so far...
# Inserted 826000 records so far...
# Inserted 826500 records so far...
# Inserted 827000 records so far...
# Inserted 827500 records so far...
# Inserted 828000 records so far...
# Inserted 828500 records so far...
# Inserted 829000 records so far...
# Inserted 829500 records so far...
# Inserted 830000 records so far...
# Inserted 830500 records so far...
# Inserted 831000 records so far...
# Inserted 831500 records so far...
# Inserted 832000 records so far...
# Inserted 832500 records so far...
# Inserted 833000 records so far...
# Inserted 833500 records so far...
# Inserted 834000 records so far...
# Inserted 834500 records so far...
# Inserted 835000 records so far...
# Inserted 835500 records so far...
# Inserted 836000 records so far...
# Inserted 836500 records so far...
# Inserted 837000 records so far...
# Inserted 837500 records so far...
# Inserted 838000 records so far...
# Inserted 838500 records so far...
# Inserted 839000 records so far...
# Inserted 839500 records so far...
# Inserted 840000 records so far...
# Inserted 840500 records so far...
# Inserted 841000 records so far...
# Inserted 841500 records so far...
# Inserted 842000 records so far...
# Inserted 842500 records so far...
# Inserted 843000 records so far...
# Inserted 843500 records so far...
# Inserted 844000 records so far...
# Inserted 844500 records so far...
# Inserted 845000 records so far...
# Inserted 845500 records so far...
# Inserted 846000 records so far...
# Inserted 846500 records so far...
# Inserted 847000 records so far...
# Inserted 847500 records so far...
# Inserted 848000 records so far...
# Inserted 848500 records so far...
# Inserted 849000 records so far...
# Inserted 849500 records so far...
# Inserted 850000 records so far...
# Inserted 850500 records so far...
# Inserted 851000 records so far...
# Inserted 851500 records so far...
# Inserted 852000 records so far...
# Inserted 852500 records so far...
# Inserted 853000 records so far...
# Inserted 853500 records so far...
# Inserted 854000 records so far...
# Inserted 854500 records so far...
# Inserted 855000 records so far...
# Inserted 855500 records so far...
# Inserted 856000 records so far...
# Inserted 856500 records so far...
# Inserted 857000 records so far...
# Inserted 857500 records so far...
# Inserted 858000 records so far...
# Inserted 858500 records so far...
# Inserted 859000 records so far...
# Inserted 859500 records so far...
# Inserted 860000 records so far...
# Inserted 860500 records so far...
# Inserted 861000 records so far...
# Inserted 861500 records so far...
# Inserted 862000 records so far...
# Inserted 862500 records so far...
# Inserted 863000 records so far...
# Inserted 863500 records so far...
# Inserted 864000 records so far...
# Inserted 864500 records so far...
# Inserted 865000 records so far...
# Inserted 865500 records so far...
# Inserted 866000 records so far...
# Inserted 866500 records so far...
# Inserted 867000 records so far...
# Inserted 867500 records so far...
# Inserted 868000 records so far...
# Inserted 868500 records so far...
# Inserted 869000 records so far...
# Inserted 869500 records so far...
# Inserted 870000 records so far...
# Inserted 870500 records so far...
# Inserted 871000 records so far...
# Inserted 871500 records so far...
# Inserted 872000 records so far...
# Inserted 872500 records so far...
# Inserted 873000 records so far...
# Inserted 873500 records so far...
# Inserted 874000 records so far...
# Inserted 874500 records so far...
# Inserted 875000 records so far...
# Inserted 875500 records so far...
# Inserted 876000 records so far...
# Inserted 876500 records so far...
# Inserted 877000 records so far...
# Inserted 877500 records so far...
# Inserted 878000 records so far...
# Inserted 878500 records so far...
# Inserted 879000 records so far...
# Inserted 879500 records so far...
# Inserted 880000 records so far...
# Inserted 880500 records so far...
# Inserted 881000 records so far...
# Inserted 881500 records so far...
# Inserted 882000 records so far...
# Inserted 882500 records so far...
# Inserted 883000 records so far...
# Inserted 883500 records so far...
# Inserted 884000 records so far...
# Inserted 884500 records so far...
# Inserted 885000 records so far...
# Inserted 885500 records so far...
# Inserted 886000 records so far...
# Inserted 886500 records so far...
# Inserted 887000 records so far...
# Inserted 887500 records so far...
# Inserted 888000 records so far...
# Inserted 888500 records so far...
# Inserted 889000 records so far...
# Inserted 889500 records so far...
# Inserted 890000 records so far...
# Inserted 890500 records so far...
# Inserted 891000 records so far...
# Inserted 891500 records so far...
# Inserted 892000 records so far...
# Inserted 892500 records so far...
# Inserted 893000 records so far...
# Inserted 893500 records so far...
# Inserted 894000 records so far...
# Inserted 894500 records so far...
# Inserted 895000 records so far...
# Inserted 895500 records so far...
# Inserted 896000 records so far...
# Inserted 896500 records so far...
# Inserted 897000 records so far...
# Inserted 897500 records so far...
# Inserted 898000 records so far...
# Inserted 898500 records so far...
# Inserted 899000 records so far...
# Inserted 899500 records so far...
# Inserted 900000 records so far...
# Inserted 900500 records so far...
# Inserted 901000 records so far...
# Inserted 901500 records so far...
# Inserted 902000 records so far...
# Inserted 902500 records so far...
# Inserted 903000 records so far...
# Inserted 903500 records so far...
# Inserted 904000 records so far...
# Inserted 904500 records so far...
# Inserted 905000 records so far...
# Inserted 905500 records so far...
# Inserted 906000 records so far...
# Inserted 906500 records so far...
# Inserted 907000 records so far...
# Inserted 907500 records so far...
# Inserted 908000 records so far...
# Inserted 908500 records so far...
# Inserted 909000 records so far...
# Inserted 909500 records so far...
# Inserted 910000 records so far...
# Inserted 910500 records so far...
# Inserted 911000 records so far...
# Inserted 911500 records so far...
# Inserted 912000 records so far...
# Inserted 912500 records so far...
# Inserted 913000 records so far...
# Inserted 913500 records so far...
# Inserted 914000 records so far...
# Inserted 914500 records so far...
# Inserted 915000 records so far...
# Inserted 915500 records so far...
# Inserted 916000 records so far...
# Inserted 916500 records so far...
# Inserted 917000 records so far...
# Inserted 917500 records so far...
# Inserted 918000 records so far...
# Inserted 918500 records so far...
# Inserted 919000 records so far...
# Inserted 919500 records so far...
# Inserted 920000 records so far...
# Inserted 920500 records so far...
# Inserted 921000 records so far...
# Inserted 921500 records so far...
# Inserted 922000 records so far...
# Inserted 922500 records so far...
# Inserted 923000 records so far...
# Inserted 923500 records so far...
# Inserted 924000 records so far...
# Inserted 924500 records so far...
# Inserted 925000 records so far...
# Inserted 925500 records so far...
# Inserted 926000 records so far...
# Inserted 926500 records so far...
# Inserted 927000 records so far...
# Inserted 927500 records so far...
# Inserted 928000 records so far...
# Inserted 928500 records so far...
# Inserted 929000 records so far...
# Inserted 929500 records so far...
# Inserted 930000 records so far...
# Inserted 930500 records so far...
# Inserted 931000 records so far...
# Inserted 931500 records so far...
# Inserted 932000 records so far...
# Inserted 932500 records so far...
# Inserted 933000 records so far...
# Inserted 933500 records so far...
# Inserted 934000 records so far...
# Inserted 934500 records so far...
# Inserted 935000 records so far...
# Inserted 935500 records so far...
# Inserted 936000 records so far...
# Inserted 936500 records so far...
# Inserted 937000 records so far...
# Inserted 937500 records so far...
# Inserted 938000 records so far...
# Inserted 938500 records so far...
# Inserted 939000 records so far...
# Inserted 939500 records so far...
# Inserted 940000 records so far...
# Inserted 940500 records so far...
# Inserted 941000 records so far...
# Inserted 941500 records so far...
# Inserted 942000 records so far...
# Inserted 942500 records so far...
# Inserted 943000 records so far...
# Inserted 943500 records so far...
# Inserted 944000 records so far...
# Inserted 944500 records so far...
# Inserted 945000 records so far...
# Inserted 945500 records so far...
# Inserted 946000 records so far...
# Inserted 946500 records so far...
# Inserted 947000 records so far...
# Inserted 947500 records so far...
# Inserted 948000 records so far...
# Inserted 948500 records so far...
# Inserted 949000 records so far...
# Inserted 949500 records so far...
# Inserted 950000 records so far...
# Inserted 950500 records so far...
# Inserted 951000 records so far...
# Inserted 951500 records so far...
# Inserted 952000 records so far...
# Inserted 952500 records so far...
# Inserted 953000 records so far...
# Inserted 953500 records so far...
# Inserted 954000 records so far...
# Inserted 954500 records so far...
# Inserted 955000 records so far...
# Inserted 955500 records so far...
# Inserted 956000 records so far...
# Inserted 956500 records so far...
# Inserted 957000 records so far...
# Inserted 957500 records so far...
# Inserted 958000 records so far...
# Inserted 958500 records so far...
# Inserted 959000 records so far...
# Inserted 959500 records so far...
# Inserted 960000 records so far...
# Inserted 960500 records so far...
# Inserted 961000 records so far...
# Inserted 961500 records so far...
# Inserted 962000 records so far...
# Inserted 962500 records so far...
# Inserted 963000 records so far...
# Inserted 963500 records so far...
# Inserted 964000 records so far...
# Inserted 964500 records so far...
# Inserted 965000 records so far...
# Inserted 965500 records so far...
# Inserted 966000 records so far...
# Inserted 966500 records so far...
# Inserted 967000 records so far...
# Inserted 967500 records so far...
# Inserted 968000 records so far...
# Inserted 968500 records so far...
# Inserted 969000 records so far...
# Inserted 969500 records so far...
# Inserted 970000 records so far...
# Inserted 970500 records so far...
# Inserted 971000 records so far...
# Inserted 971500 records so far...
# Inserted 972000 records so far...
# Inserted 972500 records so far...
# Inserted 973000 records so far...
# Inserted 973500 records so far...
# Inserted 974000 records so far...
# Inserted 974500 records so far...
# Inserted 975000 records so far...
# Inserted 975500 records so far...
# Inserted 976000 records so far...
# Inserted 976500 records so far...
# Inserted 977000 records so far...
# Inserted 977500 records so far...
# Inserted 978000 records so far...
# Inserted 978500 records so far...
# Inserted 979000 records so far...
# Inserted 979500 records so far...
# Inserted 980000 records so far...
# Inserted 980500 records so far...
# Inserted 981000 records so far...
# Inserted 981500 records so far...
# Inserted 982000 records so far...
# Inserted 982500 records so far...
# Inserted 983000 records so far...
# Inserted 983500 records so far...
# Inserted 984000 records so far...
# Inserted 984500 records so far...
# Inserted 985000 records so far...
# Inserted 985500 records so far...
# Inserted 986000 records so far...
# Inserted 986500 records so far...
# Inserted 987000 records so far...
# Inserted 987500 records so far...
# Inserted 988000 records so far...
# Inserted 988500 records so far...
# Inserted 989000 records so far...
# Inserted 989500 records so far...
# Inserted 990000 records so far...
# Inserted 990500 records so far...
# Inserted 991000 records so far...
# Inserted 991500 records so far...
# Inserted 992000 records so far...
# Inserted 992500 records so far...
# Inserted 993000 records so far...
# Inserted 993500 records so far...
# Inserted 994000 records so far...
# Inserted 994500 records so far...
# Inserted 995000 records so far...
# Inserted 995500 records so far...
# Inserted 996000 records so far...
# Inserted 996500 records so far...
# Inserted 997000 records so far...
# Inserted 997500 records so far...
# Inserted 998000 records so far...
# Inserted 998500 records so far...
# Inserted 999000 records so far...
# Inserted 999500 records so far...
# Inserted 1000000 records so far...
# Inserted 1000500 records so far...
# Inserted 1001000 records so far...
# Inserted 1001500 records so far...
# Inserted 1002000 records so far...
# Inserted 1002500 records so far...
# Inserted 1003000 records so far...
# Inserted 1003500 records so far...
# Inserted 1004000 records so far...
# Inserted 1004500 records so far...
# Inserted 1005000 records so far...
# Inserted 1005500 records so far...
# Inserted 1006000 records so far...
# Inserted 1006500 records so far...
# Inserted 1007000 records so far...
# Inserted 1007500 records so far...
# Inserted 1008000 records so far...
# Inserted 1008500 records so far...
# Inserted 1009000 records so far...
# Inserted 1009500 records so far...
# Inserted 1010000 records so far...
# Inserted 1010500 records so far...
# Inserted 1011000 records so far...
# Inserted 1011500 records so far...
# Inserted 1012000 records so far...
# Inserted 1012500 records so far...
# Inserted 1013000 records so far...
# Inserted 1013500 records so far...
# Inserted 1014000 records so far...
# Inserted 1014500 records so far...
# Inserted 1015000 records so far...
# Inserted 1015500 records so far...
# Inserted 1016000 records so far...
# Inserted 1016500 records so far...
# Inserted 1017000 records so far...
# Inserted 1017500 records so far...
# Inserted 1018000 records so far...
# Inserted 1018500 records so far...
# Inserted 1019000 records so far...
# Inserted 1019500 records so far...
# Inserted 1020000 records so far...
# Inserted 1020500 records so far...
# Inserted 1021000 records so far...
# Inserted 1021500 records so far...
# Inserted 1022000 records so far...
# Inserted 1022500 records so far...
# Inserted 1023000 records so far...
# Inserted 1023500 records so far...
# Inserted 1024000 records so far...
# Inserted 1024500 records so far...
# Inserted 1025000 records so far...
# Inserted 1025500 records so far...
# Inserted 1026000 records so far...
# Inserted 1026500 records so far...
# Inserted 1027000 records so far...
# Inserted 1027500 records so far...
# Inserted 1028000 records so far...
# Inserted 1028500 records so far...
# Inserted 1029000 records so far...
# Inserted 1029500 records so far...
# Inserted 1030000 records so far...
# Inserted 1030500 records so far...
# Inserted 1031000 records so far...
# Inserted 1031500 records so far...
# Inserted 1032000 records so far...
# Inserted 1032500 records so far...
# Inserted 1033000 records so far...
# Inserted 1033500 records so far...
# Inserted 1034000 records so far...
# Inserted 1034500 records so far...
# Inserted 1035000 records so far...
# Inserted 1035500 records so far...
# Inserted 1036000 records so far...
# Inserted 1036500 records so far...
# Inserted 1037000 records so far...
# Inserted 1037500 records so far...
# Inserted 1038000 records so far...
# Inserted 1038500 records so far...
# Inserted 1039000 records so far...
# Inserted 1039500 records so far...
# Inserted 1040000 records so far...
# Inserted 1040500 records so far...
# Inserted 1041000 records so far...
# Inserted 1041500 records so far...
# Inserted 1042000 records so far...
# Inserted 1042500 records so far...
# Inserted 1043000 records so far...
# Inserted 1043500 records so far...
# Inserted 1044000 records so far...
# Inserted 1044500 records so far...
# Inserted 1045000 records so far...
# Inserted 1045500 records so far...
# Inserted 1046000 records so far...
# Inserted 1046500 records so far...
# Inserted 1047000 records so far...
# Inserted 1047500 records so far...
# Inserted 1048000 records so far...
# Inserted 1048500 records so far...
# Inserted 1049000 records so far...
# Inserted 1049500 records so far...
# Inserted 1050000 records so far...
# Inserted 1050500 records so far...
# Inserted 1051000 records so far...
# Inserted 1051500 records so far...
# Inserted 1052000 records so far...
# Inserted 1052500 records so far...
# Inserted 1053000 records so far...
# Inserted 1053500 records so far...
# Inserted 1054000 records so far...
# Inserted 1054500 records so far...
# Inserted 1055000 records so far...
# Inserted 1055500 records so far...
# Inserted 1056000 records so far...
# Inserted 1056500 records so far...
# Inserted 1057000 records so far...
# Inserted 1057500 records so far...
# Inserted 1058000 records so far...
# Inserted 1058500 records so far...
# Inserted 1059000 records so far...
# Inserted 1059500 records so far...
# Inserted 1060000 records so far...
# Inserted 1060500 records so far...
# Inserted 1061000 records so far...
# Inserted 1061500 records so far...
# Inserted 1062000 records so far...
# Inserted 1062500 records so far...
# Inserted 1063000 records so far...
# Inserted 1063500 records so far...
# Inserted 1064000 records so far...
# Inserted 1064500 records so far...
# Inserted 1065000 records so far...
# Inserted 1065500 records so far...
# Inserted 1066000 records so far...
# Inserted 1066500 records so far...
# Inserted 1067000 records so far...
# Inserted 1067500 records so far...
# Inserted 1068000 records so far...
# Inserted 1068500 records so far...
# Inserted 1069000 records so far...
# Inserted 1069500 records so far...
# Inserted 1070000 records so far...
# Inserted 1070500 records so far...
# Inserted 1071000 records so far...
# Inserted 1071500 records so far...
# Inserted 1072000 records so far...
# Inserted 1072500 records so far...
# Inserted 1073000 records so far...
# Inserted 1073500 records so far...
# Inserted 1074000 records so far...
# Inserted 1074500 records so far...
# Inserted 1075000 records so far...
# Inserted 1075500 records so far...
# Inserted 1076000 records so far...
# Inserted 1076500 records so far...
# Inserted 1077000 records so far...
# Inserted 1077500 records so far...
# Inserted 1078000 records so far...
# Inserted 1078500 records so far...
# Inserted 1079000 records so far...
# Inserted 1079500 records so far...
# Inserted 1080000 records so far...
# Inserted 1080500 records so far...
# Inserted 1081000 records so far...
# Inserted 1081500 records so far...
# Inserted 1082000 records so far...
# Inserted 1082500 records so far...
# Inserted 1083000 records so far...
# Inserted 1083500 records so far...
# Inserted 1084000 records so far...
# Inserted 1084500 records so far...
# Inserted 1085000 records so far...
# Inserted 1085500 records so far...
# Inserted 1086000 records so far...
# Inserted 1086500 records so far...
# Inserted 1087000 records so far...
# Inserted 1087500 records so far...
# Inserted 1088000 records so far...
# Inserted 1088500 records so far...
# Inserted 1089000 records so far...
# Inserted 1089500 records so far...
# Inserted 1090000 records so far...
# Inserted 1090500 records so far...
# Inserted 1091000 records so far...
# Inserted 1091500 records so far...
# Inserted 1092000 records so far...
# Inserted 1092500 records so far...
# Inserted 1093000 records so far...
# Inserted 1093500 records so far...
# Inserted 1094000 records so far...
# Inserted 1094500 records so far...
# Inserted 1095000 records so far...
# Inserted 1095500 records so far...
# Inserted 1096000 records so far...
# Inserted 1096500 records so far...
# Inserted 1097000 records so far...
# Inserted 1097500 records so far...
# Inserted 1098000 records so far...
# Inserted 1098500 records so far...
# Inserted 1099000 records so far...
# Inserted 1099500 records so far...
# Inserted 1100000 records so far...
# Inserted 1100500 records so far...
# Inserted 1101000 records so far...
# Inserted 1101500 records so far...
# Inserted 1102000 records so far...
# Inserted 1102500 records so far...
# Inserted 1103000 records so far...
# Inserted 1103500 records so far...
# Inserted 1104000 records so far...
# Inserted 1104500 records so far...
# Inserted 1105000 records so far...
# Inserted 1105500 records so far...
# Inserted 1106000 records so far...
# Inserted 1106500 records so far...
# Inserted 1107000 records so far...
# Inserted 1107500 records so far...
# Inserted 1108000 records so far...
# Inserted 1108500 records so far...
# Inserted 1109000 records so far...
# Inserted 1109500 records so far...
# Inserted 1110000 records so far...
# Inserted 1110500 records so far...
# Inserted 1111000 records so far...
# Inserted 1111500 records so far...
# Inserted 1112000 records so far...
# Inserted 1112500 records so far...
# Inserted 1113000 records so far...
# Inserted 1113500 records so far...
# Inserted 1114000 records so far...
# Inserted 1114500 records so far...
# Inserted 1115000 records so far...
# Inserted 1115500 records so far...
# Inserted 1116000 records so far...
# Inserted 1116500 records so far...
# Inserted 1117000 records so far...
# Inserted 1117500 records so far...
# Inserted 1118000 records so far...
# Inserted 1118500 records so far...
# Inserted 1119000 records so far...
# Inserted 1119500 records so far...
# Inserted 1120000 records so far...
# Inserted 1120500 records so far...
# Inserted 1121000 records so far...
# Inserted 1121500 records so far...
# Inserted 1122000 records so far...
# Inserted 1122500 records so far...
# Inserted 1123000 records so far...
# Inserted 1123500 records so far...
# Inserted 1124000 records so far...
# Inserted 1124500 records so far...
# Inserted 1125000 records so far...
# Inserted 1125500 records so far...
# Inserted 1126000 records so far...
# Inserted 1126500 records so far...
# Inserted 1127000 records so far...
# Inserted 1127500 records so far...
# Inserted 1128000 records so far...
# Inserted 1128500 records so far...
# Inserted 1129000 records so far...
# Inserted 1129500 records so far...
# Inserted 1130000 records so far...
# Inserted 1130500 records so far...
# Inserted 1131000 records so far...
# Inserted 1131500 records so far...
# Inserted 1132000 records so far...
# Inserted 1132500 records so far...
# Inserted 1133000 records so far...
# Inserted 1133500 records so far...
# Inserted 1134000 records so far...
# Inserted 1134500 records so far...
# Inserted 1135000 records so far...
# Inserted 1135500 records so far...
# Inserted 1136000 records so far...
# Inserted 1136500 records so far...
# Inserted 1137000 records so far...
# Inserted 1137500 records so far...
# Inserted 1138000 records so far...
# Inserted 1138500 records so far...
# Inserted 1139000 records so far...
# Inserted 1139500 records so far...
# Inserted 1140000 records so far...
# Inserted 1140500 records so far...
# Inserted 1141000 records so far...
# Inserted 1141500 records so far...
# Inserted 1142000 records so far...
# Inserted 1142500 records so far...
# Inserted 1143000 records so far...
# Inserted 1143500 records so far...
# Inserted 1144000 records so far...
# Inserted 1144500 records so far...
# Inserted 1145000 records so far...
# Inserted 1145500 records so far...
# Inserted 1146000 records so far...
# Inserted 1146500 records so far...
# Inserted 1147000 records so far...
# Inserted 1147500 records so far...
# Inserted 1148000 records so far...
# Inserted 1148500 records so far...
# Inserted 1149000 records so far...
# Inserted 1149500 records so far...
# Inserted 1150000 records so far...
# Inserted 1150500 records so far...
# Inserted 1151000 records so far...
# Inserted 1151500 records so far...
# Inserted 1152000 records so far...
# Inserted 1152500 records so far...
# Inserted 1153000 records so far...
# Inserted 1153500 records so far...
# Inserted 1154000 records so far...
# Inserted 1154500 records so far...
# Inserted 1155000 records so far...
# Inserted 1155500 records so far...
# Inserted 1156000 records so far...
# Inserted 1156500 records so far...
# Inserted 1157000 records so far...
# Inserted 1157500 records so far...
# Inserted 1158000 records so far...
# Inserted 1158500 records so far...
# Inserted 1159000 records so far...
# Inserted 1159500 records so far...
# Inserted 1160000 records so far...
# Inserted 1160500 records so far...
# Inserted 1161000 records so far...
# Inserted 1161500 records so far...
# Inserted 1162000 records so far...
# Inserted 1162500 records so far...
# Inserted 1163000 records so far...
# Inserted 1163500 records so far...
# Inserted 1164000 records so far...
# Inserted 1164500 records so far...
# Inserted 1165000 records so far...
# Inserted 1165500 records so far...
# Inserted 1166000 records so far...
# Inserted 1166500 records so far...
# Inserted 1167000 records so far...
# Inserted 1167500 records so far...
# Inserted 1168000 records so far...
# Inserted 1168500 records so far...
# Inserted 1169000 records so far...
# Inserted 1169500 records so far...
# Inserted 1170000 records so far...
# Inserted 1170500 records so far...
# Inserted 1171000 records so far...
# Inserted 1171500 records so far...
# Inserted 1172000 records so far...
# Inserted 1172500 records so far...
# Inserted 1173000 records so far...
# Inserted 1173500 records so far...
# Inserted 1174000 records so far...
# Inserted 1174500 records so far...
# Inserted 1175000 records so far...
# Inserted 1175500 records so far...
# Inserted 1176000 records so far...
# Inserted 1176500 records so far...
# Inserted 1177000 records so far...
# Inserted 1177500 records so far...
# Inserted 1178000 records so far...
# Inserted 1178500 records so far...
# Inserted 1179000 records so far...
# Inserted 1179500 records so far...
# Inserted 1180000 records so far...
# Inserted 1180500 records so far...
# Inserted 1181000 records so far...
# Inserted 1181500 records so far...
# Inserted 1182000 records so far...
# Inserted 1182500 records so far...
# Inserted 1183000 records so far...
# Inserted 1183500 records so far...
# Inserted 1184000 records so far...
# Inserted 1184500 records so far...
# Inserted 1185000 records so far...
# Inserted 1185500 records so far...
# Inserted 1186000 records so far...
# Inserted 1186500 records so far...
# Inserted 1187000 records so far...
# Inserted 1187500 records so far...
# Inserted 1188000 records so far...
# Inserted 1188500 records so far...
# Inserted 1189000 records so far...
# Inserted 1189500 records so far...
# Inserted 1190000 records so far...
# Inserted 1190500 records so far...
# Inserted 1191000 records so far...
# Inserted 1191500 records so far...
# Inserted 1192000 records so far...
# Inserted 1192500 records so far...
# Inserted 1193000 records so far...
# Inserted 1193500 records so far...
# Inserted 1194000 records so far...
# Inserted 1194500 records so far...
# Inserted 1195000 records so far...
# Inserted 1195500 records so far...
# Inserted 1196000 records so far...
# Inserted 1196500 records so far...
# Inserted 1197000 records so far...
# Inserted 1197500 records so far...
# Inserted 1198000 records so far...
# Inserted 1198500 records so far...
# Inserted 1199000 records so far...
# Inserted 1199500 records so far...
# Inserted 1200000 records so far...
# Inserted 1200500 records so far...
# Inserted 1201000 records so far...
# Inserted 1201500 records so far...
# Inserted 1202000 records so far...
# Inserted 1202500 records so far...
# Inserted 1203000 records so far...
# Inserted 1203500 records so far...
# Inserted 1204000 records so far...
# Inserted 1204500 records so far...
# Inserted 1205000 records so far...
# Inserted 1205500 records so far...
# Inserted 1206000 records so far...
# Inserted 1206500 records so far...
# Inserted 1207000 records so far...
# Inserted 1207500 records so far...
# Inserted 1208000 records so far...
# Inserted 1208500 records so far...
# Inserted 1209000 records so far...
# Inserted 1209500 records so far...
# Inserted 1210000 records so far...
# Inserted 1210500 records so far...
# Inserted 1211000 records so far...
# Inserted 1211500 records so far...
# Inserted 1212000 records so far...
# Inserted 1212500 records so far...
# Inserted 1213000 records so far...
# Inserted 1213500 records so far...
# Inserted 1214000 records so far...
# Inserted 1214500 records so far...
# Inserted 1215000 records so far...
# Inserted 1215500 records so far...
# Inserted 1216000 records so far...
# Inserted 1216500 records so far...
# Inserted 1217000 records so far...
# Inserted 1217500 records so far...
# Inserted 1218000 records so far...
# Inserted 1218500 records so far...
# Inserted 1219000 records so far...
# Inserted 1219500 records so far...
# Inserted 1220000 records so far...
# Inserted 1220500 records so far...
# Inserted 1221000 records so far...
# Inserted 1221500 records so far...
# Inserted 1222000 records so far...
# Inserted 1222500 records so far...
# Inserted 1223000 records so far...
# Inserted 1223500 records so far...
# Inserted 1224000 records so far...
# Inserted 1224500 records so far...
# Inserted 1225000 records so far...
# Inserted 1225500 records so far...
# Inserted 1226000 records so far...
# Inserted 1226500 records so far...
# Inserted 1227000 records so far...
# Inserted 1227500 records so far...
# Inserted 1228000 records so far...
# Inserted 1228500 records so far...
# Inserted 1229000 records so far...
# Inserted 1229500 records so far...
# Inserted 1230000 records so far...
# Inserted 1230500 records so far...
# Inserted 1231000 records so far...
# Inserted 1231500 records so far...
# Inserted 1232000 records so far...
# Inserted 1232500 records so far...
# Inserted 1233000 records so far...
# Inserted 1233500 records so far...
# Inserted 1234000 records so far...
# Inserted 1234500 records so far...
# Inserted 1235000 records so far...
# Inserted 1235500 records so far...
# Inserted 1236000 records so far...
# Inserted 1236500 records so far...
# Inserted 1237000 records so far...
# Inserted 1237500 records so far...
# Inserted 1238000 records so far...
# Inserted 1238500 records so far...
# Inserted 1239000 records so far...
# Inserted 1239500 records so far...
# Inserted 1240000 records so far...
# Inserted 1240500 records so far...
# Inserted 1241000 records so far...
# Inserted 1241500 records so far...
# Inserted 1242000 records so far...
# Inserted 1242500 records so far...
# Inserted 1243000 records so far...
# Inserted 1243500 records so far...
# Inserted 1244000 records so far...
# Inserted 1244500 records so far...
# Inserted 1245000 records so far...
# Inserted 1245500 records so far...
# Inserted 1246000 records so far...
# Inserted 1246500 records so far...
# Inserted 1247000 records so far...
# Inserted 1247500 records so far...
# Inserted 1248000 records so far...
# Inserted 1248500 records so far...
# Inserted 1249000 records so far...
# Inserted 1249500 records so far...
# Inserted 1250000 records so far...
# Inserted 1250500 records so far...
# Inserted 1251000 records so far...
# Inserted 1251500 records so far...
# Inserted 1252000 records so far...
# Inserted 1252500 records so far...
# Inserted 1253000 records so far...
# Inserted 1253500 records so far...
# Inserted 1254000 records so far...
# Inserted 1254500 records so far...
# Inserted 1255000 records so far...
# Inserted 1255500 records so far...
# Inserted 1256000 records so far...
# Inserted 1256500 records so far...
# Inserted 1257000 records so far...
# Inserted 1257500 records so far...
# Inserted 1258000 records so far...
# Inserted 1258500 records so far...
# Inserted 1259000 records so far...
# Inserted 1259500 records so far...
# Inserted 1260000 records so far...
# Inserted 1260500 records so far...
# Inserted 1261000 records so far...
# Inserted 1261500 records so far...
# Inserted 1262000 records so far...
# Inserted 1262500 records so far...
# Inserted 1263000 records so far...
# Inserted 1263500 records so far...
# Inserted 1264000 records so far...
# Inserted 1264500 records so far...
# Inserted 1265000 records so far...
# Inserted 1265500 records so far...
# Inserted 1266000 records so far...
# Inserted 1266500 records so far...
# Inserted 1267000 records so far...
# Inserted 1267500 records so far...
# Inserted 1268000 records so far...
# Inserted 1268500 records so far...
# Inserted 1269000 records so far...
# Inserted 1269500 records so far...
# Inserted 1270000 records so far...
# Inserted 1270500 records so far...
# Inserted 1271000 records so far...
# Inserted 1271500 records so far...
# Inserted 1272000 records so far...
# Inserted 1272500 records so far...
# Inserted 1273000 records so far...
# Inserted 1273500 records so far...
# Inserted 1274000 records so far...
# Inserted 1274500 records so far...
# Inserted 1275000 records so far...
# Inserted 1275500 records so far...
# Inserted 1276000 records so far...
# Inserted 1276500 records so far...
# Inserted 1277000 records so far...
# Inserted 1277500 records so far...
# Inserted 1278000 records so far...
# Inserted 1278500 records so far...
# Inserted 1279000 records so far...
# Inserted 1279500 records so far...
# Inserted 1280000 records so far...
# Inserted 1280500 records so far...
# Inserted 1281000 records so far...
# Inserted 1281500 records so far...
# Inserted 1282000 records so far...
# Inserted 1282500 records so far...
# Inserted 1283000 records so far...
# Inserted 1283500 records so far...
# Inserted 1284000 records so far...
# Inserted 1284500 records so far...
# Inserted 1285000 records so far...
# Inserted 1285500 records so far...
# Inserted 1286000 records so far...
# Inserted 1286500 records so far...
# Inserted 1287000 records so far...
# Inserted 1287500 records so far...
# Inserted 1288000 records so far...
# Inserted 1288500 records so far...
# Inserted 1289000 records so far...
# Inserted 1289500 records so far...
# Inserted 1290000 records so far...
# Inserted 1290500 records so far...
# Inserted 1291000 records so far...
# Inserted 1291500 records so far...
# Inserted 1292000 records so far...
# Inserted 1292500 records so far...
# Inserted 1293000 records so far...
# Inserted 1293500 records so far...
# Inserted 1294000 records so far...
# Inserted 1294500 records so far...
# Inserted 1295000 records so far...
# Inserted 1295500 records so far...
# Inserted 1296000 records so far...
# Inserted 1296500 records so far...
# Inserted 1297000 records so far...
# Inserted 1297500 records so far...
# Inserted 1298000 records so far...
# Inserted 1298500 records so far...
# Inserted 1299000 records so far...
# Inserted 1299500 records so far...
# Inserted 1300000 records so far...
# Inserted 1300500 records so far...
# Inserted 1301000 records so far...
# Inserted 1301500 records so far...
# Inserted 1302000 records so far...
# Inserted 1302500 records so far...
# Inserted 1303000 records so far...
# Inserted 1303500 records so far...
# Inserted 1304000 records so far...
# Inserted 1304500 records so far...
# Inserted 1305000 records so far...
# Inserted 1305500 records so far...
# Inserted 1306000 records so far...
# Inserted 1306500 records so far...
# Inserted 1307000 records so far...
# Inserted 1307500 records so far...
# Inserted 1308000 records so far...
# Inserted 1308500 records so far...
# Inserted 1309000 records so far...
# Inserted 1309500 records so far...
# Inserted 1310000 records so far...
# Inserted 1310500 records so far...
# Inserted 1311000 records so far...
# Inserted 1311500 records so far...
# Inserted 1312000 records so far...
# Inserted 1312500 records so far...
# Inserted 1313000 records so far...
# Inserted 1313500 records so far...
# Inserted 1314000 records so far...
# Inserted 1314500 records so far...
# Inserted 1315000 records so far...
# Inserted 1315500 records so far...
# Inserted 1316000 records so far...
# Inserted 1316500 records so far...
# Inserted 1317000 records so far...
# Inserted 1317500 records so far...
# Inserted 1318000 records so far...
# Inserted 1318500 records so far...
# Inserted 1319000 records so far...
# Inserted 1319500 records so far...
# Inserted 1320000 records so far...
# Inserted 1320500 records so far...
# Inserted 1321000 records so far...
# Inserted 1321500 records so far...
# Inserted 1322000 records so far...
# Inserted 1322500 records so far...
# Inserted 1323000 records so far...
# Inserted 1323500 records so far...
# Inserted 1324000 records so far...
# Inserted 1324500 records so far...
# Inserted 1325000 records so far...
# Inserted 1325500 records so far...
# Inserted 1326000 records so far...
# Inserted 1326500 records so far...
# Inserted 1327000 records so far...
# Inserted 1327500 records so far...
# Inserted 1328000 records so far...
# Inserted 1328500 records so far...
# Inserted 1329000 records so far...
# Inserted 1329500 records so far...
# Inserted 1330000 records so far...
# Inserted 1330500 records so far...
# Inserted 1331000 records so far...
# Inserted 1331500 records so far...
# Inserted 1332000 records so far...
# Inserted 1332500 records so far...
# Inserted 1333000 records so far...
# Inserted 1333500 records so far...
# Inserted 1334000 records so far...
# Inserted 1334500 records so far...
# Inserted 1335000 records so far...
# Inserted 1335500 records so far...
# Inserted 1336000 records so far...
# Inserted 1336500 records so far...
# Inserted 1337000 records so far...
# Inserted 1337500 records so far...
# Inserted 1338000 records so far...
# Inserted 1338500 records so far...
# Inserted 1339000 records so far...
# Inserted 1339500 records so far...
# Inserted 1340000 records so far...
# Inserted 1340500 records so far...
# Inserted 1341000 records so far...
# Inserted 1341500 records so far...
# Inserted 1342000 records so far...
# Inserted 1342500 records so far...
# Inserted 1343000 records so far...
# Inserted 1343500 records so far...
# Inserted 1344000 records so far...
# Inserted 1344500 records so far...
# Inserted 1345000 records so far...
# Inserted 1345500 records so far...
# Inserted 1346000 records so far...
# Inserted 1346500 records so far...
# Inserted 1347000 records so far...
# Inserted 1347500 records so far...
# Inserted 1348000 records so far...
# Inserted 1348500 records so far...
# Inserted 1349000 records so far...
# Inserted 1349500 records so far...
# Inserted 1350000 records so far...
# Inserted 1350500 records so far...
# Inserted 1351000 records so far...
# Inserted 1351500 records so far...
# Inserted 1352000 records so far...
# Inserted 1352500 records so far...
# Inserted 1353000 records so far...
# Inserted 1353500 records so far...
# Inserted 1354000 records so far...
# Inserted 1354500 records so far...
# Inserted 1355000 records so far...
# Inserted 1355500 records so far...
# Inserted 1356000 records so far...
# Inserted 1356500 records so far...
# Inserted 1357000 records so far...
# Inserted 1357500 records so far...
# Inserted 1358000 records so far...
# Inserted 1358500 records so far...
# Inserted 1359000 records so far...
# Inserted 1359500 records so far...
# Inserted 1360000 records so far...
# Inserted 1360500 records so far...
# Inserted 1361000 records so far...
# Inserted 1361500 records so far...
# Inserted 1362000 records so far...
# Inserted 1362500 records so far...
# Inserted 1363000 records so far...
# Inserted 1363500 records so far...
# Inserted 1364000 records so far...
# Inserted 1364500 records so far...
# Inserted 1365000 records so far...
# Inserted 1365500 records so far...
# Inserted 1366000 records so far...
# Inserted 1366500 records so far...
# Inserted 1367000 records so far...
# Inserted 1367500 records so far...
# Inserted 1368000 records so far...
# Inserted 1368500 records so far...
# Inserted 1369000 records so far...
# Inserted 1369500 records so far...
# Inserted 1370000 records so far...
# Inserted 1370500 records so far...
# Inserted 1371000 records so far...
# Inserted 1371500 records so far...
# Inserted 1372000 records so far...
# Inserted 1372500 records so far...
# Inserted 1373000 records so far...
# Inserted 1373500 records so far...
# Inserted 1374000 records so far...
# Inserted 1374500 records so far...
# Inserted 1375000 records so far...
# Inserted 1375500 records so far...
# Inserted 1376000 records so far...
# Inserted 1376500 records so far...
# Inserted 1377000 records so far...
# Inserted 1377500 records so far...
# Inserted 1378000 records so far...
# Inserted 1378500 records so far...
# Inserted 1379000 records so far...
# Inserted 1379500 records so far...
# Inserted 1380000 records so far...
# Inserted 1380500 records so far...
# Inserted 1381000 records so far...
# Inserted 1381500 records so far...
# Inserted 1382000 records so far...
# Inserted 1382500 records so far...
# Inserted 1383000 records so far...
# Inserted 1383500 records so far...
# Inserted 1384000 records so far...
# Inserted 1384500 records so far...
# Inserted 1385000 records so far...
# Inserted 1385500 records so far...
# Inserted 1386000 records so far...
# Inserted 1386500 records so far...
# Inserted 1387000 records so far...
# Inserted 1387500 records so far...
# Inserted 1388000 records so far...
# Inserted 1388500 records so far...
# Inserted 1389000 records so far...
# Inserted 1389500 records so far...
# Inserted 1390000 records so far...
# Inserted 1390500 records so far...
# Inserted 1391000 records so far...
# Inserted 1391500 records so far...
# Inserted 1392000 records so far...
# Inserted 1392500 records so far...
# Inserted 1393000 records so far...
# Inserted 1393500 records so far...
# Inserted 1394000 records so far...
# Inserted 1394500 records so far...
# Inserted 1395000 records so far...
# Inserted 1395500 records so far...
# Inserted 1396000 records so far...
# Inserted 1396500 records so far...
# Inserted 1397000 records so far...
# Inserted 1397500 records so far...
# Inserted 1398000 records so far...
# Inserted 1398500 records so far...
# Inserted 1399000 records so far...
# Inserted 1399500 records so far...
# Inserted 1400000 records so far...
# Inserted 1400500 records so far...
# Inserted 1401000 records so far...
# Inserted 1401500 records so far...
# Inserted 1402000 records so far...
# Inserted 1402500 records so far...
# Inserted 1403000 records so far...
# Inserted 1403500 records so far...
# Inserted 1404000 records so far...
# Inserted 1404500 records so far...
# Inserted 1405000 records so far...
# Inserted 1405500 records so far...
# Inserted 1406000 records so far...
# Inserted 1406500 records so far...
# Inserted 1407000 records so far...
# Inserted 1407500 records so far...
# Inserted 1408000 records so far...
# Inserted 1408500 records so far...
# Inserted 1409000 records so far...
# Inserted 1409500 records so far...
# Inserted 1410000 records so far...
# Inserted 1410500 records so far...
# Inserted 1411000 records so far...
# Inserted 1411500 records so far...
# Inserted 1412000 records so far...
# Inserted 1412500 records so far...
# Inserted 1413000 records so far...
# Inserted 1413500 records so far...
# Inserted 1414000 records so far...
# Inserted 1414500 records so far...
# Inserted 1415000 records so far...
# Inserted 1415500 records so far...
# Inserted 1416000 records so far...
# Inserted 1416500 records so far...
# Inserted 1417000 records so far...
# Inserted 1417500 records so far...
# Inserted 1418000 records so far...
# Inserted 1418500 records so far...
# Inserted 1419000 records so far...
# Inserted 1419500 records so far...
# Inserted 1420000 records so far...
# Inserted 1420500 records so far...
# Inserted 1421000 records so far...
# Inserted 1421500 records so far...
# Inserted 1422000 records so far...
# Inserted 1422500 records so far...
# Inserted 1423000 records so far...
# Inserted 1423500 records so far...
# Inserted 1424000 records so far...
# Inserted 1424500 records so far...
# Inserted 1425000 records so far...
# Inserted 1425500 records so far...
# Inserted 1426000 records so far...
# Inserted 1426500 records so far...
# Inserted 1427000 records so far...
# Inserted 1427500 records so far...
# Inserted 1428000 records so far...
# Inserted 1428500 records so far...
# Inserted 1429000 records so far...
# Inserted 1429500 records so far...
# Inserted 1430000 records so far...
# Inserted 1430500 records so far...
# Inserted 1431000 records so far...
# Inserted 1431500 records so far...
# Inserted 1432000 records so far...
# Inserted 1432500 records so far...
# Inserted 1433000 records so far...
# Inserted 1433500 records so far...
# Inserted 1434000 records so far...
# Inserted 1434500 records so far...
# Inserted 1435000 records so far...
# Inserted 1435500 records so far...
# Inserted 1436000 records so far...
# Inserted 1436500 records so far...
# Inserted 1437000 records so far...
# ...
# Inserted 3016500 records so far...
# Inserted 3017000 records so far...
# Inserted 3017500 records so far...
# Inserted 3018000 records so far...
# Inserted 3018500 records so far...
# Inserted 3019000 records so far...
# Inserted 3019500 records so far...
# Inserted 3020000 records so far...
# Inserted 3020500 records so far...
# Inserted 3021000 records so far...
# Inserted 3021500 records so far...
# Inserted 3022000 records so far...
# Inserted 3022500 records so far...
# Inserted 3023000 records so far...
# Inserted 3023500 records so far...
# Inserted 3024000 records so far...
# Inserted 3024500 records so far...
# Inserted 3025000 records so far...
# Inserted 3025500 records so far...
# Inserted 3026000 records so far...
# Inserted 3026500 records so far...
# Inserted 3027000 records so far...
# Inserted 3027500 records so far...
# Inserted 3028000 records so far...
# Inserted 3028500 records so far...
# Inserted 3029000 records so far...
# Inserted 3029500 records so far...
# Inserted 3030000 records so far...
# Inserted 3030500 records so far...
# Inserted 3031000 records so far...
# Inserted 3031500 records so far...
# Inserted 3032000 records so far...
# Inserted 3032500 records so far...
# Inserted 3033000 records so far...
# Inserted 3033500 records so far...
# Inserted 3034000 records so far...
# Inserted 3034500 records so far...
# Inserted 3035000 records so far...
# Inserted 3035500 records so far...
# Inserted 3036000 records so far...
# Inserted 3036500 records so far...
# Inserted 3037000 records so far...
# Inserted 3037500 records so far...
# Inserted 3038000 records so far...
# Inserted 3038500 records so far...
# Inserted 3039000 records so far...
# Inserted 3039500 records so far...
# Inserted 3040000 records so far...
# Inserted 3040500 records so far...
# Inserted 3041000 records so far...
# Inserted 3041500 records so far...
# Inserted 3042000 records so far...
# Inserted 3042500 records so far...
# Inserted 3043000 records so far...
# Inserted 3043500 records so far...
# Inserted 3044000 records so far...
# Inserted 3044500 records so far...
# Inserted 3045000 records so far...
# Inserted 3045500 records so far...
# Inserted 3046000 records so far...
# Inserted 3046500 records so far...
# Inserted 3047000 records so far...
# Inserted 3047500 records so far...
# Inserted 3048000 records so far...
# Inserted 3048500 records so far...
# Inserted 3049000 records so far...
# Inserted 3049500 records so far...
# Inserted 3050000 records so far...
# Inserted 3050500 records so far...
# Inserted 3051000 records so far...
# Inserted 3051500 records so far...
# Inserted 3052000 records so far...
# Inserted 3052500 records so far...
# Inserted 3053000 records so far...
# Inserted 3053500 records so far...
# Inserted 3054000 records so far...
# Inserted 3054500 records so far...
# Inserted 3055000 records so far...
# Inserted 3055500 records so far...
# Inserted 3056000 records so far...
# Inserted 3056500 records so far...
# Inserted 3057000 records so far...
# Inserted 3057500 records so far...
# Inserted 3058000 records so far...
# Inserted 3058500 records so far...
# Inserted 3059000 records so far...
# Inserted 3059500 records so far...
# Inserted 3060000 records so far...
# Inserted 3060500 records so far...
# Inserted 3061000 records so far...
# Inserted 3061500 records so far...
# Inserted 3062000 records so far...
# Inserted 3062500 records so far...
# Inserted 3063000 records so far...
# Inserted 3063500 records so far...
# Inserted 3064000 records so far...
# Inserted 3064500 records so far...
# Inserted 3065000 records so far...
# Inserted 3065500 records so far...
# Inserted 3066000 records so far...
# Inserted 3066500 records so far...
# Inserted 3067000 records so far...
# Inserted 3067500 records so far...
# Inserted 3068000 records so far...
# Inserted 3068500 records so far...
# Inserted 3069000 records so far...
# Inserted 3069500 records so far...
# Inserted 3070000 records so far...
# Inserted 3070500 records so far...
# Inserted 3071000 records so far...
# Inserted 3071500 records so far...
# Inserted 3072000 records so far...
# Inserted 3072500 records so far...
# Inserted 3073000 records so far...
# Inserted 3073500 records so far...
# Inserted 3074000 records so far...
# Inserted 3074500 records so far...
# Inserted 3075000 records so far...
# Inserted 3075500 records so far...
# Inserted 3076000 records so far...
# Inserted 3076500 records so far...
# Inserted 3077000 records so far...
# Inserted 3077500 records so far...
# Inserted 3078000 records so far...
# Inserted 3078500 records so far...
# Inserted 3079000 records so far...
# Inserted 3079500 records so far...
# Inserted 3080000 records so far...
# Inserted 3080500 records so far...
# Inserted 3081000 records so far...
# Inserted 3081500 records so far...
# Inserted 3082000 records so far...
# Inserted 3082500 records so far...
# Inserted 3083000 records so far...
# Inserted 3083500 records so far...
# Inserted 3084000 records so far...
# Inserted 3084500 records so far...
# Inserted 3085000 records so far...
# Inserted 3085500 records so far...
# Inserted 3086000 records so far...
# Inserted 3086500 records so far...
# Inserted 3087000 records so far...
# Inserted 3087500 records so far...
# Inserted 3088000 records so far...
# Inserted 3088500 records so far...
# Inserted 3089000 records so far...
# Inserted 3089500 records so far...
# Inserted 3090000 records so far...
# Inserted 3090500 records so far...
# Inserted 3091000 records so far...
# Inserted 3091500 records so far...
# Inserted 3092000 records so far...
# Inserted 3092500 records so far...
# Inserted 3093000 records so far...
# Inserted 3093500 records so far...
# Inserted 3094000 records so far...
# Inserted 3094500 records so far...
# Inserted 3095000 records so far...
# Inserted 3095500 records so far...
# Inserted 3096000 records so far...
# Inserted 3096500 records so far...
# Inserted 3097000 records so far...
# Inserted 3097500 records so far...
# Inserted 3098000 records so far...
# Inserted 3098500 records so far...
# Inserted 3099000 records so far...
# Inserted 3099500 records so far...
# Inserted 3100000 records so far...
# Inserted 3100500 records so far...
# Inserted 3101000 records so far...
# Inserted 3101500 records so far...
# Inserted 3102000 records so far...
# Inserted 3102500 records so far...
# Inserted 3103000 records so far...
# Inserted 3103500 records so far...
# Inserted 3104000 records so far...
# Inserted 3104500 records so far...
# Inserted 3105000 records so far...
# Inserted 3105500 records so far...
# Inserted 3106000 records so far...
# Inserted 3106500 records so far...
# Inserted 3107000 records so far...
# Inserted 3107500 records so far...
# Inserted 3108000 records so far...
# Inserted 3108500 records so far...
# Inserted 3109000 records so far...
# Inserted 3109500 records so far...
# Inserted 3110000 records so far...
# Inserted 3110500 records so far...
# Inserted 3111000 records so far...
# Inserted 3111500 records so far...
# Inserted 3112000 records so far...
# Inserted 3112500 records so far...
# Inserted 3113000 records so far...
# Inserted 3113500 records so far...
# Inserted 3114000 records so far...
# Inserted 3114500 records so far...
# Inserted 3115000 records so far...
# Inserted 3115500 records so far...
# Inserted 3116000 records so far...
# Inserted 3116500 records so far...
# Inserted 3117000 records so far...
# Inserted 3117500 records so far...
# Inserted 3118000 records so far...
# Inserted 3118500 records so far...
# Inserted 3119000 records so far...
# Inserted 3119500 records so far...
# Inserted 3120000 records so far...
# Inserted 3120500 records so far...
# Inserted 3121000 records so far...
# Inserted 3121500 records so far...
# Inserted 3122000 records so far...
# Inserted 3122500 records so far...
# Inserted 3123000 records so far...
# Inserted 3123500 records so far...
# Inserted 3124000 records so far...
# Inserted 3124500 records so far...
# Inserted 3125000 records so far...
# Inserted 3125500 records so far...
# Inserted 3126000 records so far...
# Inserted 3126500 records so far...
# Inserted 3127000 records so far...
# Inserted 3127500 records so far...
# Inserted 3128000 records so far...
# Inserted 3128500 records so far...
# Inserted 3129000 records so far...
# Inserted 3129500 records so far...
# Inserted 3130000 records so far...
# Inserted 3130500 records so far...
# Inserted 3131000 records so far...
# Inserted 3131500 records so far...
# Inserted 3132000 records so far...
# Inserted 3132500 records so far...
# Inserted 3133000 records so far...
# Inserted 3133500 records so far...
# Inserted 3134000 records so far...
# Inserted 3134500 records so far...
# Inserted 3135000 records so far...
# Inserted 3135500 records so far...
# Inserted 3136000 records so far...
# Inserted 3136500 records so far...
# Inserted 3137000 records so far...
# Inserted 3137500 records so far...
# Inserted 3138000 records so far...
# Inserted 3138500 records so far...
# Inserted 3139000 records so far...
# Inserted 3139500 records so far...
# Inserted 3140000 records so far...
# Inserted 3140500 records so far...
# Inserted 3141000 records so far...
# Inserted 3141500 records so far...
# Inserted 3142000 records so far...
# Inserted 3142500 records so far...
# Inserted 3143000 records so far...
# Inserted 3143500 records so far...
# Inserted 3144000 records so far...
# Inserted 3144500 records so far...
# Inserted 3145000 records so far...
# Inserted 3145500 records so far...
# Inserted 3146000 records so far...
# Inserted 3146500 records so far...
# Inserted 3147000 records so far...
# Inserted 3147500 records so far...
# Inserted 3148000 records so far...
# Inserted 3148500 records so far...
# Inserted 3149000 records so far...
# Inserted 3149500 records so far...
# Inserted 3150000 records so far...
# Inserted 3150500 records so far...
# Inserted 3151000 records so far...
# Inserted 3151500 records so far...
# Inserted 3152000 records so far...
# Inserted 3152500 records so far...
# Inserted 3153000 records so far...
# Inserted 3153500 records so far...
# Inserted 3154000 records so far...
# Inserted 3154500 records so far...
# Inserted 3155000 records so far...
# Inserted 3155500 records so far...
# Inserted 3156000 records so far...
# Inserted 3156500 records so far...
# Inserted 3157000 records so far...
# Inserted 3157500 records so far...
# Inserted 3158000 records so far...
# Inserted 3158500 records so far...
# Inserted 3159000 records so far...
# Inserted 3159500 records so far...
# Inserted 3160000 records so far...
# Inserted 3160500 records so far...
# Inserted 3161000 records so far...
# Inserted 3161500 records so far...
# Inserted 3162000 records so far...
# Inserted 3162500 records so far...
# Inserted 3163000 records so far...
# Inserted 3163500 records so far...
# Inserted 3164000 records so far...
# Inserted 3164500 records so far...
# Inserted 3165000 records so far...
# Inserted 3165500 records so far...
# Inserted 3166000 records so far...
# Inserted 3166500 records so far...
# Inserted 3167000 records so far...
# Inserted 3167500 records so far...
# Inserted 3168000 records so far...
# Inserted 3168500 records so far...
# Inserted 3169000 records so far...
# Inserted 3169500 records so far...
# Inserted 3170000 records so far...
# Inserted 3170500 records so far...
# Inserted 3171000 records so far...
# Inserted 3171500 records so far...
# Inserted 3172000 records so far...
# Inserted 3172500 records so far...
# Inserted 3173000 records so far...
# Inserted 3173500 records so far...
# Inserted 3174000 records so far...
# Inserted 3174500 records so far...
# Inserted 3175000 records so far...
# Inserted 3175500 records so far...
# Inserted 3176000 records so far...
# Inserted 3176500 records so far...
# Inserted 3177000 records so far...
# Inserted 3177500 records so far...
# Inserted 3178000 records so far...
# Inserted 3178500 records so far...
# Inserted 3179000 records so far...
# Inserted 3179500 records so far...
# Inserted 3180000 records so far...
# Inserted 3180500 records so far...
# Inserted 3181000 records so far...
# Inserted 3181500 records so far...
# Inserted 3182000 records so far...
# Inserted 3182500 records so far...
# Inserted 3183000 records so far...
# Inserted 3183500 records so far...
# Inserted 3184000 records so far...
# Inserted 3184500 records so far...
# Inserted 3185000 records so far...
# Inserted 3185500 records so far...
# Inserted 3186000 records so far...
# Inserted 3186500 records so far...
# Inserted 3187000 records so far...
# Inserted 3187500 records so far...
# Inserted 3188000 records so far...
# Inserted 3188500 records so far...
# Inserted 3189000 records so far...
# Inserted 3189500 records so far...
# Inserted 3190000 records so far...
# Inserted 3190500 records so far...
# Inserted 3191000 records so far...
# Inserted 3191500 records so far...
# Inserted 3192000 records so far...
# Inserted 3192500 records so far...
# Inserted 3193000 records so far...
# Inserted 3193500 records so far...
# Inserted 3194000 records so far...
# Inserted 3194500 records so far...
# Inserted 3195000 records so far...
# Inserted 3195500 records so far...
# Inserted 3196000 records so far...
# Inserted 3196500 records so far...
# Inserted 3197000 records so far...
# Inserted 3197500 records so far...
# Inserted 3198000 records so far...
# Inserted 3198500 records so far...
# Inserted 3199000 records so far...
# Inserted 3199500 records so far...
# Inserted 3200000 records so far...
# Inserted 3200500 records so far...
# Inserted 3201000 records so far...
# Inserted 3201500 records so far...
# Inserted 3202000 records so far...
# Inserted 3202500 records so far...
# Inserted 3203000 records so far...
# Inserted 3203500 records so far...
# Inserted 3204000 records so far...
# Inserted 3204500 records so far...
# Inserted 3205000 records so far...
# Inserted 3205500 records so far...
# Inserted 3206000 records so far...
# Inserted 3206500 records so far...
# Inserted 3207000 records so far...
# Inserted 3207500 records so far...
# Inserted 3208000 records so far...
# Inserted 3208500 records so far...
# Inserted 3209000 records so far...
# Inserted 3209500 records so far...
# Inserted 3210000 records so far...
# Inserted 3210500 records so far...
# Inserted 3211000 records so far...
# Inserted 3211500 records so far...
# Inserted 3212000 records so far...
# Inserted 3212500 records so far...
# Inserted 3213000 records so far...
# Inserted 3213500 records so far...
# Inserted 3214000 records so far...
# Inserted 3214500 records so far...
# Inserted 3215000 records so far...
# Inserted 3215500 records so far...
# Inserted 3216000 records so far...
# Inserted 3216500 records so far...
# Inserted 3217000 records so far...
# Inserted 3217500 records so far...
# Inserted 3218000 records so far...
# Inserted 3218500 records so far...
# Inserted 3219000 records so far...
# Inserted 3219500 records so far...
# Inserted 3220000 records so far...
# Inserted 3220500 records so far...
# Inserted 3221000 records so far...
# Inserted 3221500 records so far...
# Inserted 3222000 records so far...
# Inserted 3222500 records so far...
# Inserted 3223000 records so far...
# Inserted 3223500 records so far...
# Inserted 3224000 records so far...
# Inserted 3224500 records so far...
# Inserted 3225000 records so far...
# Inserted 3225500 records so far...
# Inserted 3226000 records so far...
# Inserted 3226500 records so far...
# Inserted 3227000 records so far...
# Inserted 3227500 records so far...
# Inserted 3228000 records so far...
# Inserted 3228500 records so far...
# Inserted 3229000 records so far...
# Inserted 3229500 records so far...
# Inserted 3230000 records so far...
# Inserted 3230500 records so far...
# Inserted 3231000 records so far...
# Inserted 3231500 records so far...
# Inserted 3232000 records so far...
# Inserted 3232500 records so far...
# Inserted 3233000 records so far...
# Inserted 3233500 records so far...
# Inserted 3234000 records so far...
# Inserted 3234500 records so far...
# Inserted 3235000 records so far...
# Inserted 3235500 records so far...
# Inserted 3236000 records so far...
# Inserted 3236500 records so far...
# Inserted 3237000 records so far...
# Inserted 3237500 records so far...
# Inserted 3238000 records so far...
# Inserted 3238500 records so far...
# Inserted 3239000 records so far...
# Inserted 3239500 records so far...
# Inserted 3240000 records so far...
# Inserted 3240500 records so far...
# Inserted 3241000 records so far...
# Inserted 3241500 records so far...
# Inserted 3242000 records so far...
# Inserted 3242500 records so far...
# Inserted 3243000 records so far...
# Inserted 3243500 records so far...
# Inserted 3244000 records so far...
# Inserted 3244500 records so far...
